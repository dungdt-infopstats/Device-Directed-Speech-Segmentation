# %% [markdown]
# <a href="https://colab.research.google.com/github/10udCryp7/TV-command-synthesis/blob/main/src_prototype/Phase4_NoiseAugmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import random
import numpy as np
import torch
import torchaudio
from copy import deepcopy
import json
from typing import List, Dict

class NoiseAugmentor:
    def __init__(self,
                 noise_folders,
                 target_sr=16000,
                 snr_range=(-5, 20),
                 prepend_range_s=(2, 5),   # giây
                 append_range_s=(2, 5),    # giây
                 overlap_range_s=(2, 5),   # giây
                 seed=None):
        self.noise_files = []
        for folder in noise_folders:
            for f in os.listdir(folder):
                if f.endswith(".wav"):
                    self.noise_files.append(os.path.join(folder, f))
        assert len(self.noise_files) > 0, "No noise files found!"

        self.sr = target_sr
        self.snr_range = snr_range
        self.prepend_range_s = prepend_range_s
        self.append_range_s = append_range_s
        self.overlap_range_s = overlap_range_s
        if seed is not None:
          random.seed(seed)
          np.random.seed(seed)
          torch.manual_seed(seed)

    def _sec2samples(self, sec):
        return int(sec * self.sr)

    def _load_audio(self, path):
        wav, sr = torchaudio.load(path)
        wav = wav.mean(dim=0, keepdim=True)  # mono
        if sr != self.sr:
            wav = torchaudio.functional.resample(wav, sr, self.sr)
        return wav.squeeze(0)

    def _scale_noise(self, clean, noise, snr_db):
        Px = clean.pow(2).mean()
        Pn = noise.pow(2).mean() + 1e-12
        k = torch.sqrt(Px / (Pn * (10**(snr_db/10))))
        return noise * k

    def _sample_noise_file(self):
        f = random.choice(self.noise_files)
        return self._load_audio(f), f

    def _sample_noise_segment(self, noise, dur_samples):
        if noise.shape[-1] <= dur_samples:
            # noise ngắn quá → lặp/pad
            reps = (dur_samples // noise.shape[-1]) + 1
            noise = noise.repeat(reps)[:dur_samples]
            return noise
        else:
            start = random.randint(0, noise.shape[-1] - dur_samples)
            return noise[start:start+dur_samples]

    def _shift_labels(self, labels, shift_s):
        shifted = []
        for l in labels:
            shifted.append({
                "label": l["label"],
                "start": l["start"] + shift_s,
                "end": l["end"] + shift_s
            })
        return shifted

    def _append_noise_label(self, labels, start_s, end_s):
        labels = deepcopy(labels)
        labels.append({"label": "noise", "start": start_s, "end": end_s})
        return labels

    def _merge_overlap_labels(self, labels, noise_start, noise_end):
        new_labels = deepcopy(labels)
        add_noise = []
        for l in labels:
            if l["label"] == "active":
                if noise_end <= l["start"] or noise_start >= l["end"]:
                    continue  # không chồng
                # noise nhô ra bên trái
                if noise_start < l["start"]:
                    add_noise.append({"label": "noise", "start": noise_start, "end": l["start"]})
                # noise nhô ra bên phải
                if noise_end > l["end"]:
                    add_noise.append({"label": "noise", "start": l["end"], "end": noise_end})
        new_labels.extend(add_noise)
        return new_labels

    def _load_labels(self, json_path: str) -> List[Dict]:
        """
        Đọc file JSON label (dạng list segment) và trả về list dict.

        Args:
            json_path (str): đường dẫn tới file .json

        Returns:
            List[Dict]: danh sách label segment, mỗi phần tử có keys: "label", "start", "end"
        """
        with open(json_path, "r", encoding="utf-8") as f:
            labels = json.load(f)

        # đảm bảo dữ liệu hợp lệ (optional)
        cleaned = []
        for seg in labels:
            if all(k in seg for k in ["label", "start", "end"]):
                cleaned.append({
                    "label": str(seg["label"]),
                    "start": float(seg["start"]),
                    "end": float(seg["end"])
                })
        return cleaned


    def augment(self, clean_path, labels_path, mode=None):
        labels = self._load_labels(labels_path)
        clean = self._load_audio(clean_path)
        speech_len = clean.shape[-1]
        speech_dur = speech_len / self.sr

        noise, noise_path = self._sample_noise_file()
        if mode is None:
            mode = random.choice(["overlap","prepend", "overlap", "append", "overlap"])
        snr_db = random.uniform(*self.snr_range)

        if mode == "prepend":
            dur_s = random.uniform(*self.prepend_range_s)
            dur_samples = self._sec2samples(dur_s)
            seg = self._sample_noise_segment(noise, dur_samples)
            out = torch.cat([seg, clean])
            new_labels = self._shift_labels(labels, dur_s)
            new_labels = self._append_noise_label(new_labels, 0, dur_s)

        elif mode == "append":
            dur_s = random.uniform(*self.append_range_s)
            dur_samples = self._sec2samples(dur_s)
            seg = self._sample_noise_segment(noise, dur_samples)
            out = torch.cat([clean, seg])
            new_labels = deepcopy(labels)
            new_labels = self._append_noise_label(new_labels, speech_dur, speech_dur + dur_s)

        elif mode == "overlap":
            dur_s = random.uniform(*self.overlap_range_s)
            dur_samples = min(self._sec2samples(dur_s), speech_len)
            offset = random.randint(0, speech_len - dur_samples)
            offset_s = offset / self.sr
            seg = self._sample_noise_segment(noise, dur_samples)

            noise_aligned = torch.zeros_like(clean)
            noise_aligned[offset:offset+dur_samples] = seg
            noise_scaled = self._scale_noise(clean, noise_aligned, snr_db)
            out = clean + noise_scaled

            noise_start = offset_s
            noise_end = offset_s + dur_s
            new_labels = self._merge_overlap_labels(labels, noise_start, noise_end)

        metadata = {
            "clean_path": clean_path,
            "noise_path": noise_path,
            "mode": mode,
            "snr_db": snr_db,
            "labels": new_labels
        }
        return out, metadata

# %%
# !gdown 1ri2VCkL9gkwvgxstEbE6zTqS1GpgSXZy
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1ri2VCkL9gkwvgxstEbE6zTqS1GpgSXZy
# From (redirected): https://drive.google.com/uc?id=1ri2VCkL9gkwvgxstEbE6zTqS1GpgSXZy&confirm=t&uuid=4e914a25-dad3-45e5-b84b-4499570e2eff
# To: /content/sample-5000-vctk-concat.zip
# 100% 413M/413M [00:09<00:00, 45.8MB/s]

# %%
# !unzip -q sample-5000-vctk-concat.zip

# %%
# !wget -O musan.tar.gz https://www.openslr.org/resources/17/musan.tar.gz
# Out:
# --2025-08-28 03:36:33--  https://www.openslr.org/resources/17/musan.tar.gz
# Resolving www.openslr.org (www.openslr.org)... 136.243.171.4
# Connecting to www.openslr.org (www.openslr.org)|136.243.171.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 11086114085 (10G) [application/x-gzip]
# Saving to: ‘musan.tar.gz’
#
# musan.tar.gz        100%[===================>]  10.32G  13.4MB/s    in 12m 49s
#
# 2025-08-28 03:49:23 (13.8 MB/s) - ‘musan.tar.gz’ saved [11086114085/11086114085]

# %%
# !tar -xzf musan.tar.gz

# %%
NOISE_FOLDERS = [
    "/content/musan/speech/us-gov",
    "/content/musan/speech/librivox"
]

# %%
import os
import json
import soundfile as sf
from tqdm import tqdm  # thêm tqdm

OUTPUT_DIR = "/content/concat_speech/augmented"

def main():
    na = NoiseAugmentor(
        noise_folders=NOISE_FOLDERS
    )

    input_root = "/content/concat_speech/sample"

    # dùng tqdm để có progress bar
    for file_folder in tqdm(os.listdir(input_root), desc="Augmenting"):
        folder_path = os.path.join(input_root, file_folder)
        if not os.path.isdir(folder_path):
            continue

        audio_name = f"{file_folder}_concat.wav"
        json_name = f"{file_folder}.json"

        file_path = os.path.join(folder_path, audio_name)
        label_path = os.path.join(folder_path, json_name)

        # augment
        out, meta = na.augment(
            clean_path=file_path,
            labels_path=label_path,
        )

        # make output folder
        out_folder = os.path.join(OUTPUT_DIR, file_folder)
        os.makedirs(out_folder, exist_ok=True)

        # export audio (soundfile expects [T, C] or [T,])
        out_audio_path = os.path.join(out_folder, audio_name.replace("_concat.wav", "_aug.wav"))
        sf.write(out_audio_path, out.squeeze(0).numpy().T, na.sr)

        # export metadata
        out_json_path = os.path.join(out_folder, json_name.replace(".json", "_aug.json"))
        with open(out_json_path, "w", encoding="utf-8") as f:
            json.dump(meta, f, indent=2, ensure_ascii=False)

# %%
main()
# Out:
# Augmenting: 100%|██████████| 3021/3021 [04:09<00:00, 12.11it/s]

# %%
# !zip aug_speech.zip concat_speech/augmented -r
# Out:
# Streaming output truncated to the last 5000 lines.
#   adding: concat_speech/augmented/chain_active_ba6bb8b3/chain_active_ba6bb8b3_aug.wav (deflated 16%)
#   adding: concat_speech/augmented/chain_active_ba6bb8b3/chain_active_ba6bb8b3_aug.json (deflated 42%)
#   adding: concat_speech/augmented/single_active_8b7f03b1/ (stored 0%)
#   adding: concat_speech/augmented/single_active_8b7f03b1/single_active_8b7f03b1_aug.json (deflated 50%)
#   adding: concat_speech/augmented/single_active_8b7f03b1/single_active_8b7f03b1_aug.wav (deflated 17%)
#   adding: concat_speech/augmented/non_active_da020fa8/ (stored 0%)
#   adding: concat_speech/augmented/non_active_da020fa8/non_active_da020fa8_aug.json (deflated 42%)
#   adding: concat_speech/augmented/non_active_da020fa8/non_active_da020fa8_aug.wav (deflated 13%)
#   adding: concat_speech/augmented/single_active_af39ead4/ (stored 0%)
#   adding: concat_speech/augmented/single_active_af39ead4/single_active_af39ead4_aug.json (deflated 48%)
#   adding: concat_speech/augmented/single_active_af39ead4/single_active_af39ead4_aug.wav (deflated 8%)
#   adding: concat_speech/augmented/non_active_f6eb6226/ (stored 0%)
#   adding: concat_speech/augmented/non_active_f6eb6226/non_active_f6eb6226_aug.wav (deflated 16%)
#   adding: concat_speech/augmented/non_active_f6eb6226/non_active_f6eb6226_aug.json (deflated 42%)
#   adding: concat_speech/augmented/chain_mix_55e2e1d1/ (stored 0%)
#   adding: concat_speech/augmented/chain_mix_55e2e1d1/chain_mix_55e2e1d1_aug.json (deflated 53%)
#   adding: concat_speech/augmented/chain_mix_55e2e1d1/chain_mix_55e2e1d1_aug.wav (deflated 12%)
#   adding: concat_speech/augmented/non_active_f001a602/ (stored 0%)
#   adding: concat_speech/augmented/non_active_f001a602/non_active_f001a602_aug.wav (deflated 10%)
#   adding: concat_speech/augmented/non_active_f001a602/non_active_f001a602_aug.json (deflated 48%)
#   adding: concat_speech/augmented/chain_mix_5b3ea3e6/ (stored 0%)
#   adding: concat_speech/augmented/chain_mix_5b3ea3e6/chain_mix_5b3ea3e6_aug.json (deflated 54%)
#   adding: concat_speech/augmented/chain_mix_5b3ea3e6/chain_mix_5b3ea3e6_aug.wav (deflated 14%)
#   adding: concat_speech/augmented/single_mix_7977a6a2/ (stored 0%)
#   adding: concat_speech/augmented/single_mix_7977a6a2/single_mix_7977a6a2_aug.wav (deflated 20%)
#   adding: concat_speech/augmented/single_mix_7977a6a2/single_mix_7977a6a2_aug.json (deflated 56%)
#   adding: concat_speech/augmented/chain_mix_66bb29e6/ (stored 0%)
#   adding: concat_speech/augmented/chain_mix_66bb29e6/chain_mix_66bb29e6_aug.json (deflated 62%)
#   adding: concat_speech/augmented/chain_mix_66bb29e6/chain_mix_66bb29e6_aug.wav (deflated 18%)
#   adding: concat_speech/augmented/chain_active_4af3d45b/ (stored 0%)
#   adding: concat_speech/augmented/chain_active_4af3d45b/chain_active_4af3d45b_aug.json (deflated 42%)
#   adding: concat_speech/augmented/chain_active_4af3d45b/chain_active_4af3d45b_aug.wav (deflated 20%)
#   adding: concat_speech/augmented/single_active_1f727a67/ (stored 0%)
#   adding: concat_speech/augmented/single_active_1f727a67/single_active_1f727a67_aug.json (deflated 48%)
#   adding: concat_speech/augmented/single_active_1f727a67/single_active_1f727a67_aug.wav (deflated 19%)
#   adding: concat_speech/augmented/chain_mix_4d56957f/ (stored 0%)
#   adding: concat_speech/augmented/chain_mix_4d56957f/chain_mix_4d56957f_aug.json (deflated 53%)
#   adding: concat_speech/augmented/chain_mix_4d56957f/chain_mix_4d56957f_aug.wav (deflated 10%)
#   adding: concat_speech/augmented/single_active_75fba1d6/ (stored 0%)
#   adding: concat_speech/augmented/single_active_75fba1d6/single_active_75fba1d6_aug.json (deflated 51%)
#   adding: concat_speech/augmented/single_active_75fba1d6/single_active_75fba1d6_aug.wav (deflated 21%)
#   adding: concat_speech/augmented/chain_active_8aca331e/ (stored 0%)
#   adding: concat_speech/augmented/chain_active_8aca331e/chain_active_8aca331e_aug.json (deflated 50%)
#   adding: concat_speech/augmented/chain_active_8aca331e/chain_active_8aca331e_aug.wav (deflated 15%)
#   adding: concat_speech/augmented/single_active_c6a8dd37/ (stored 0%)
#   adding: concat_speech/augmented/single_active_c6a8dd37/single_active_c6a8dd37_aug.wav (deflated 14%)
#   adding: concat_speech/augmented/single_active_c6a8dd37/single_active_c6a8dd37_aug.json (deflated 48%)
#   adding: concat_speech/augmented/chain_active_84d367bf/ (stored 0%)
#   adding: concat_speech/augmented/chain_active_84d367bf/chain_active_84d367bf_aug.json (deflated 47%)
#   adding: concat_speech/augmented/chain_active_84d367bf/chain_active_84d367bf_aug.wav (deflated 11%)
#   adding: concat_speech/augmented/single_mix_72a100bf/ (stored 0%)
#   adding: concat_speech/augmented/single_mix_72a100bf/single_mix_72a100bf_aug.json (deflated 56%)
#   adding: concat_speech/augmented/single_mix_72a100bf/single_mix_72a100bf_aug.wav (deflated 28%)
#   adding: concat_speech/augmented/chain_active_8aa05679/ (stored 0%)
#   adding: concat_speech/augmented/chain_active_8aa05679/chain_active_8aa05679_aug.json (deflated 48%)
#   adding: concat_speech/augmented/chain_active_8aa05679/chain_active_8aa05679_aug.wav (deflated 12%)
#   adding: concat_speech/augmented/non_active_87c544b3/ (stored 0%)
#   adding: concat_speech/augmented/non_active_87c544b3/non_active_87c544b3_aug.json (deflated 50%)
#   adding: concat_speech/augmented/non_active_87c544b3/non_active_87c544b3_aug.wav (deflated 12%)
#   adding: concat_speech/augmented/non_active_07af6c96/ (stored 0%)
#   adding: concat_speech/augmented/non_active_07af6c96/non_active_07af6c96_aug.json (deflated 43%)
#   adding: concat_speech/augmented/non_active_07af6c96/non_active_07af6c96_aug.wav (deflated 23%)
#   adding: concat_speech/augmented/chain_active_e06cddd5/ (stored 0%)
#   adding: concat_speech/augmented/chain_active_e06cddd5/chain_active_e06cddd5_aug.json (deflated 50%)
#   adding: concat_speech/augmented/chain_active_e06cddd5/chain_active_e06cddd5_aug.wav (deflated 8%)
#   adding: concat_speech/augmented/non_active_bdd1c0fc/ (stored 0%)
#   adding: concat_speech/augmented/non_active_bdd1c0fc/non_active_bdd1c0fc_aug.wav (deflated 19%)
#   adding: concat_speech/augmented/non_active_bdd1c0fc/non_active_bdd1c0fc_aug.json (deflated 42%)
#   adding: concat_speech/augmented/chain_active_f9952165/ (stored 0%)
#   adding: concat_speech/augmented/chain_active_f9952165/chain_active_f9952165_aug.json (deflated 48%)
#   adding: concat_speech/augmented/chain_active_f9952165/chain_active_f9952165_aug.wav (deflated 18%)
#   adding: concat_speech/augmented/non_active_a3c37e99/ (stored 0%)
#   adding: concat_speech/augmented/non_active_a3c37e99/non_active_a3c37e99_aug.json (deflated 42%)
#   adding: concat_speech/augmented/non_active_a3c37e99/non_active_a3c37e99_aug.wav (deflated 17%)
#   adding: concat_speech/augmented/non_active_228a5bed/ (stored 0%)
#   adding: concat_speech/augmented/non_active_228a5bed/non_active_228a5bed_aug.wav (deflated 18%)
#   adding: concat_speech/augmented/non_active_228a5bed/non_active_228a5bed_aug.json (deflated 50%)
#   adding: concat_speech/augmented/chain_active_96fc83bd/ (stored 0%)
#   adding: concat_speech/augmented/chain_active_96fc83bd/chain_active_96fc83bd_aug.wav (deflated 9%)
#   adding: concat_speech/augmented/chain_active_96fc83bd/chain_active_96fc83bd_aug.json (deflated 48%)
#   adding: concat_speech/augmented/single_mix_21192680/ (stored 0%)
#   adding: concat_speech/augmented/single_mix_21192680/single_mix_21192680_aug.wav (deflated 20%)
#   adding: concat_speech/augmented/single_mix_21192680/single_mix_21192680_aug.json (deflated 48%)
#   adding: concat_speech/augmented/non_active_d680d7dc/ (stored 0%)
#   adding: concat_speech/augmented/non_active_d680d7dc/non_active_d680d7dc_aug.wav (deflated 34%)
#   adding: concat_speech/augmented/non_active_d680d7dc/non_active_d680d7dc_aug.json (deflated 43%)
#   adding: concat_speech/augmented/single_mix_a6ee12ef/ (stored 0%)
#   adding: concat_speech/augmented/single_mix_a6ee12ef/single_mix_a6ee12ef_aug.wav (deflated 11%)
#   adding: concat_speech/augmented/single_mix_a6ee12ef/single_mix_a6ee12ef_aug.json (deflated 53%)
#   adding: concat_speech/augmented/non_active_9eb452ac/ (stored 0%)
#   adding: concat_speech/augmented/non_active_9eb452ac/non_active_9eb452ac_aug.json (deflated 42%)
#   adding: concat_speech/augmented/non_active_9eb452ac/non_active_9eb452ac_aug.wav (deflated 17%)
#   adding: concat_speech/augmented/single_active_3443f25d/ (stored 0%)
#   adding: concat_speech/augmented/single_active_3443f25d/single_active_3443f25d_aug.json (deflated 48%)
#   adding: concat_speech/augmented/single_active_3443f25d/single_active_3443f25d_aug.wav (deflated 15%)
#   adding: concat_speech/augmented/single_mix_4c31841e/ (stored 0%)
#   adding: concat_speech/augmented/single_mix_4c31841e/single_mix_4c31841e_aug.json (deflated 56%)
#   adding: concat_speech/augmented/single_mix_4c31841e/single_mix_4c31841e_aug.wav (deflated 14%)
#   adding: concat_speech/augmented/single_mix_3c348301/ (stored 0%)
#   adding: concat_speech/augmented/single_mix_3c348301/single_mix_3c348301_aug.wav (deflated 19%)
#   adding: concat_speech/augmented/single_mix_3c348301/single_mix_3c348301_aug.json (deflated 53%)
#   adding: concat_speech/augmented/single_active_804ac287/ (stored 0%)
#   adding: concat_speech/augmented/single_active_804ac287/single_active_804ac287_aug.json (deflated 41%)
#   adding: concat_speech/augmented/single_active_804ac287/single_active_804ac287_aug.wav (deflated 29%)
#   adding: concat_speech/augmented/chain_mix_3df06880/ (stored 0%)
#   adding: concat_speech/augmented/chain_mix_3df06880/chain_mix_3df06880_aug.wav (deflated 14%)
#   adding: concat_speech/augmented/chain_mix_3df06880/chain_mix_3df06880_aug.json (deflated 54%)
#   adding: concat_speech/augmented/chain_mix_882c0f9b/ (stored 0%)
#   adding: concat_speech/augmented/chain_mix_882c0f9b/chain_mix_882c0f9b_aug.json (deflated 56%)
#   adding: concat_speech/augmented/chain_mix_882c0f9b/chain_mix_882c0f9b_aug.wav (deflated 20%)
#   adding: concat_speech/augmented/chain_active_cc2925e3/ (stored 0%)
#   adding: concat_speech/augmented/chain_active_cc2925e3/chain_active_cc2925e3_aug.json (deflated 48%)
#   adding: concat_speech/augmented/chain_active_cc2925e3/chain_active_cc2925e3_aug.wav (deflated 8%)
#   adding: concat_speech/augmented/chain_active_0a409a52/ (stored 0%)
#   adding: concat_speech/augmented/chain_active_0a409a52/chain_active_0a409a52_aug.wav (deflated 14%)
#   adding: concat_speech/augmented/chain_active_0a409a52/chain_active_0a409a52_aug.json (deflated 48%)
#   adding: concat_speech/augmented/single_mix_98a6a7d6/ (stored 0%)
#   adding: concat_speech/augmented/single_mix_98a6a7d6/single_mix_98a6a7d6_aug.json (deflated 54%)
#   adding: concat_speech/augmented/single_mix_98a6a7d6/single_mix_98a6a7d6_aug.wav (deflated 18%)
#   adding: concat_speech/augmented/single_mix_ef5ac8df/ (stored 0%)
#   adding: concat_speech/augmented/single_mix_ef5ac8df/single_mix_ef5ac8df_aug.json (deflated 53%)
#   adding: concat_speech/augmented/single_mix_ef5ac8df/single_mix_ef5ac8df_aug.wav (deflated 30%)
#   adding: concat_speech/augmented/non_active_ee92651f/ (stored 0%)
#   adding: concat_speech/augmented/non_active_ee92651f/non_active_ee92651f_aug.json (deflated 42%)
#   adding: concat_speech/augmented/non_active_ee92651f/non_active_ee92651f_aug.wav (deflated 10%)
#   adding: concat_speech/augmented/non_active_a2559b22/ (stored 0%)
#   adding: concat_speech/augmented/non_active_a2559b22/non_active_a2559b22_aug.wav (deflated 7%)
#   adding: concat_speech/augmented/non_active_a2559b22/non_active_a2559b22_aug.json (deflated 42%)
#   adding: concat_speech/augmented/chain_active_bc25d0f4/ (stored 0%)
#   adding: concat_speech/augmented/chain_active_bc25d0f4/chain_active_bc25d0f4_aug.wav (deflated 22%)
#   adding: concat_speech/augmented/chain_active_bc25d0f4/chain_active_bc25d0f4_aug.json (deflated 48%)
#   adding: concat_speech/augmented/single_mix_c102daf4/ (stored 0%)
#   adding: concat_speech/augmented/single_mix_c102daf4/single_mix_c102daf4_aug.wav (deflated 18%)
#   adding: concat_speech/augmented/single_mix_c102daf4/single_mix_c102daf4_aug.json (deflated 53%)
#   adding: concat_speech/augmented/single_mix_e9fd91ce/ (stored 0%)
#   adding: concat_speech/augmented/single_mix_e9fd91ce/single_mix_e9fd91ce_aug.json (deflated 56%)
#   adding: concat_speech/augmented/single_mix_e9fd91ce/single_mix_e9fd91ce_aug.wav (deflated 12%)
#   adding: concat_speech/augmented/non_active_d0f7cada/ (stored 0%)
#   adding: concat_speech/augmented/non_active_d0f7cada/non_active_d0f7cada_aug.wav (deflated 12%)
#   adding: concat_speech/augmented/non_active_d0f7cada/non_active_d0f7cada_aug.json (deflated 50%)
#   adding: concat_speech/augmented/single_active_639f99e6/ (stored 0%)
#   adding: concat_speech/augmented/single_active_639f99e6/single_active_639f99e6_aug.json (deflated 48%)
#   adding: concat_speech/augmented/single_active_639f99e6/single_active_639f99e6_aug.wav (deflated 25%)
#   adding: concat_speech/augmented/non_active_01c940d8/ (stored 0%)
#   adding: concat_speech/augmented/non_active_01c940d8/non_active_01c940d8_aug.wav (deflated 13%)
#   adding: concat_speech/augmented/non_active_01c940d8/non_active_01c940d8_aug.json (deflated 43%)
#   adding: concat_speech/augmented/single_mix_a38f2140/ (stored 0%)
#   adding: concat_speech/augmented/single_mix_a38f2140/single_mix_a38f2140_aug.json (deflated 62%)
#   adding: concat_speech/augmented/single_mix_a38f2140/single_mix_a38f2140_aug.wav (deflated 14%)
#   adding: concat_speech/augmented/single_mix_c099498c/ (stored 0%)
#   adding: concat_speech/augmented/single_mix_c099498c/single_mix_c099498c_aug.wav (deflated 31%)
#   adding: concat_speech/augmented/single_mix_c099498c/single_mix_c099498c_aug.json (deflated 56%)
#   adding: concat_speech/augmented/non_active_ca5f70af/ (stored 0%)
#   adding: concat_speech/augmented/non_active_ca5f70af/non_active_ca5f70af_aug.wav (deflated 24%)
#   adding: concat_speech/augmented/non_active_ca5f70af/non_active_ca5f70af_aug.json (deflated 42%)
#   adding: concat_speech/augmented/single_active_e7b32299/ (stored 0%)
#   adding: concat_speech/augmented/single_active_e7b32299/single_active_e7b32299_aug.wav (deflated 12%)
#   adding: concat_speech/augmented/single_active_e7b32299/single_active_e7b32299_aug.json (deflated 48%)
#   adding: concat_speech/augmented/chain_mix_3060a770/ (stored 0%)
#   adding: concat_speech/augmented/chain_mix_3060a770/chain_mix_3060a770_aug.json (deflated 53%)
#   adding: concat_speech/augmented/chain_mix_3060a770/chain_mix_3060a770_aug.wav (deflated 20%)
#   adding: concat_speech/augmented/chain_mix_c73bdfaa/ (stored 0%)
#   adding: concat_speech/augmented/chain_mix_c73bdfaa/chain_mix_c73bdfaa_aug.wav (deflated 10%)
#   adding: concat_speech/augmented/chain_mix_c73bdfaa/chain_mix_c73bdfaa_aug.json (deflated 53%)
#   adding: concat_speech/augmented/chain_mix_3dcbe87f/ (stored 0%)
#   adding: concat_speech/augmented/chain_mix_3dcbe87f/chain_mix_3dcbe87f_aug.wav (deflated 20%)
#   adding: concat_speech/augmented/chain_mix_3dcbe87f/chain_mix_3dcbe87f_aug.json (deflated 54%)
#   adding: concat_speech/augmented/chain_mix_d226a6e4/ (stored 0%)
#   adding: concat_speech/augmented/chain_mix_d226a6e4/chain_mix_d226a6e4_aug.json (deflated 61%)
#   adding: concat_speech/augmented/chain_mix_d226a6e4/chain_mix_d226a6e4_aug.wav (deflated 22%)
#   adding: concat_speech/augmented/chain_active_20e62ce9/ (stored 0%)
#   adding: concat_speech/augmented/chain_active_20e62ce9/chain_active_20e62ce9_aug.json (deflated 49%)
#   adding: concat_speech/augmented/chain_active_20e62ce9/chain_active_20e62ce9_aug.wav (deflated 10%)
#   adding: concat_speech/augmented/single_active_e9166c1d/ (stored 0%)
#   adding: concat_speech/augmented/single_active_e9166c1d/single_active_e9166c1d_aug.json (deflated 50%)
#   adding: concat_speech/augmented/single_active_e9166c1d/single_active_e9166c1d_aug.wav (deflated 18%)
#   adding: concat_speech/augmented/single_active_b8bdc9e2/ (stored 0%)
#   adding: concat_speech/augmented/single_active_b8bdc9e2/single_active_b8bdc9e2_aug.json (deflated 48%)
#   adding: concat_speech/augmented/single_active_b8bdc9e2/single_active_b8bdc9e2_aug.wav (deflated 7%)
#   adding: concat_speech/augmented/single_active_69120c78/ (stored 0%)
#   adding: concat_speech/augmented/single_active_69120c78/single_active_69120c78_aug.json (deflated 50%)
#   adding: concat_speech/augmented/single_active_69120c78/single_active_69120c78_aug.wav (deflated 21%)
#   adding: concat_speech/augmented/single_active_6cc7c789/ (stored 0%)
#   adding: concat_speech/augmented/single_active_6cc7c789/single_active_6cc7c789_aug.wav (deflated 11%)
#   adding: concat_speech/augmented/single_active_6cc7c789/single_active_6cc7c789_aug.json (deflated 49%)
#   adding: concat_speech/augmented/chain_active_6493d1b6/ (stored 0%)
#   adding: concat_speech/augmented/chain_active_6493d1b6/chain_active_6493d1b6_aug.wav (deflated 20%)
#   adding: concat_speech/augmented/chain_active_6493d1b6/chain_active_6493d1b6_aug.json (deflated 47%)
#   adding: concat_speech/augmented/single_mix_4f3c53ed/ (stored 0%)
#   adding: concat_speech/augmented/single_mix_4f3c53ed/single_mix_4f3c53ed_aug.json (deflated 54%)
#   adding: concat_speech/augmented/single_mix_4f3c53ed/single_mix_4f3c53ed_aug.wav (deflated 8%)
#   adding: concat_speech/augmented/single_mix_768f4556/ (stored 0%)
#   adding: concat_speech/augmented/single_mix_768f4556/single_mix_768f4556_aug.wav (deflated 20%)
#   adding: concat_speech/augmented/single_mix_768f4556/single_mix_768f4556_aug.json (deflated 56%)
#   adding: concat_speech/augmented/chain_active_3819a3a5/ (stored 0%)
#   adding: concat_speech/augmented/chain_active_3819a3a5/chain_active_3819a3a5_aug.json (deflated 48%)
#   adding: concat_speech/augmented/chain_active_3819a3a5/chain_active_3819a3a5_aug.wav (deflated 23%)
#   adding: concat_speech/augmented/single_active_ea72f697/ (stored 0%)
#   adding: concat_speech/augmented/single_active_ea72f697/single_active_ea72f697_aug.wav (deflated 14%)
#   adding: concat_speech/augmented/single_active_ea72f697/single_active_ea72f697_aug.json (deflated 48%)
#   adding: concat_speech/augmented/non_active_06d99394/ (stored 0%)
#   adding: concat_speech/augmented/non_active_06d99394/non_active_06d99394_aug.json (deflated 50%)
#   adding: concat_speech/augmented/non_active_06d99394/non_active_06d99394_aug.wav (deflated 24%)
#   adding: concat_speech/augmented/chain_mix_5144ab0f/ (stored 0%)
#   adding: concat_speech/augmented/chain_mix_5144ab0f/chain_mix_5144ab0f_aug.json (deflated 48%)
#   adding: concat_speech/augmented/chain_mix_5144ab0f/chain_mix_5144ab0f_aug.wav (deflated 15%)
#   adding: concat_speech/augmented/chain_active_86a7579c/ (stored 0%)
#   adding: concat_speech/augmented/chain_active_86a7579c/chain_active_86a7579c_aug.json (deflated 50%)
#   adding: concat_speech/augmented/chain_active_86a7579c/chain_active_86a7579c_aug.wav (deflated 10%)
#   adding: concat_speech/augmented/single_active_04b89727/ (stored 0%)
#   adding: concat_speech/augmented/single_active_04b89727/single_active_04b89727_aug.json (deflated 47%)
#   adding: concat_speech/augmented/single_active_04b89727/single_active_04b89727_aug.wav (deflated 14%)
#   adding: concat_speech/augmented/non_active_05c1f9c6/ (stored 0%)
#   adding: concat_speech/augmented/non_active_05c1f9c6/non_active_05c1f9c6_aug.json (deflated 42%)
#   adding: concat_speech/augmented/non_active_05c1f9c6/non_active_05c1f9c6_aug.wav (deflated 13%)
#   adding: concat_speech/augmented/non_active_0f3037da/ (stored 0%)
#   adding: concat_speech/augmented/non_active_0f3037da/non_active_0f3037da_aug.json (deflated 42%)
#   adding: concat_speech/augmented/non_active_0f3037da/non_active_0f3037da_aug.wav (deflated 14%)
#   adding: concat_speech/augmented/chain_mix_0063ea20/ (stored 0%)
#   adding: concat_speech/augmented/chain_mix_0063ea20/chain_mix_0063ea20_aug.wav (deflated 22%)
#   adding: concat_speech/augmented/chain_mix_0063ea20/chain_mix_0063ea20_aug.json (deflated 58%)
#   adding: concat_speech/augmented/chain_mix_d63e7a35/ (stored 0%)
#   adding: concat_speech/augmented/chain_mix_d63e7a35/chain_mix_d63e7a35_aug.wav (deflated 28%)
#   adding: concat_speech/augmented/chain_mix_d63e7a35/chain_mix_d63e7a35_aug.json (deflated 48%)
#   adding: concat_speech/augmented/non_active_7fb85bac/ (stored 0%)
#   adding: concat_speech/augmented/non_active_7fb85bac/non_active_7fb85bac_aug.json (deflated 42%)
#   adding: concat_speech/augmented/non_active_7fb85bac/non_active_7fb85bac_aug.wav (deflated 17%)
#   adding: concat_speech/augmented/single_mix_8ec693b6/ (stored 0%)
#   adding: concat_speech/augmented/single_mix_8ec693b6/single_mix_8ec693b6_aug.json (deflated 56%)
#   adding: concat_speech/augmented/single_mix_8ec693b6/single_mix_8ec693b6_aug.wav (deflated 18%)
#   adding: concat_speech/augmented/chain_mix_b57fff15/ (stored 0%)
#   adding: concat_speech/augmented/chain_mix_b57fff15/chain_mix_b57fff15_aug.json (deflated 62%)
#   adding: concat_speech/augmented/chain_mix_b57fff15/chain_mix_b57fff15_aug.wav (deflated 27%)
#   adding: concat_speech/augmented/non_active_8f4086eb/ (stored 0%)
#   adding: concat_speech/augmented/non_active_8f4086eb/non_active_8f4086eb_aug.wav (deflated 14%)
#   adding: concat_speech/augmented/non_active_8f4086eb/non_active_8f4086eb_aug.json (deflated 43%)
#   adding: concat_speech/augmented/single_mix_4942b8e7/ (stored 0%)
#   adding: concat_speech/augmented/single_mix_4942b8e7/single_mix_4942b8e7_aug.json (deflated 58%)
#   adding: concat_speech/augmented/single_mix_4942b8e7/single_mix_4942b8e7_aug.wav (deflated 11%)
#   adding: concat_speech/augmented/non_active_6eb261b1/ (stored 0%)
#   adding: concat_speech/augmented/non_active_6eb261b1/non_active_6eb261b1_aug.json (deflated 41%)
#   adding: concat_speech/augmented/non_active_6eb261b1/non_active_6eb261b1_aug.wav (deflated 13%)
#   adding: concat_speech/augmented/chain_mix_d309a21a/ (stored 0%)
#   adding: concat_speech/augmented/chain_mix_d309a21a/chain_mix_d309a21a_aug.json (deflated 65%)
#   adding: concat_speech/augmented/chain_mix_d309a21a/chain_mix_d309a21a_aug.wav (deflated 13%)
#   adding: concat_speech/augmented/chain_mix_d2a6a0b2/ (stored 0%)
#   adding: concat_speech/augmented/chain_mix_d2a6a0b2/chain_mix_d2a6a0b2_aug.wav (deflated 12%)
#   adding: concat_speech/augmented/chain_mix_d2a6a0b2/chain_mix_d2a6a0b2_aug.json (deflated 65%)
#   adding: concat_speech/augmented/single_mix_111502da/ (stored 0%)
#   adding: concat_speech/augmented/single_mix_111502da/single_mix_111502da_aug.json (deflated 56%)
#   adding: concat_speech/augmented/single_mix_111502da/single_mix_111502da_aug.wav (deflated 56%)
#   adding: concat_speech/augmented/chain_mix_afbdd14d/ (stored 0%)
#   adding: concat_speech/augmented/chain_mix_afbdd14d/chain_mix_afbdd14d_aug.wav (deflated 18%)
#   adding: concat_speech/augmented/chain_mix_afbdd14d/chain_mix_afbdd14d_aug.json (deflated 53%)
#   adding: concat_speech/augmented/single_mix_69393149/ (stored 0%)
#   adding: concat_speech/augmented/single_mix_69393149/single_mix_69393149_aug.wav (deflated 21%)
#   adding: concat_speech/augmented/single_mix_69393149/single_mix_69393149_aug.json (deflated 58%)
#   adding: concat_speech/augmented/chain_active_fdbbaed1/ (stored 0%)
#   adding: concat_speech/augmented/chain_active_fdbbaed1/chain_active_fdbbaed1_aug.json (deflated 48%)
#   adding: concat_speech/augmented/chain_active_fdbbaed1/chain_active_fdbbaed1_aug.wav (deflated 12%)
#   adding: concat_speech/augmented/non_active_2f0a2ad2/ (stored 0%)
#   adding: concat_speech/augmented/non_active_2f0a2ad2/non_active_2f0a2ad2_aug.json (deflated 43%)
#   adding: concat_speech/augmented/non_active_2f0a2ad2/non_active_2f0a2ad2_aug.wav (deflated 10%)
#   adding: concat_speech/augmented/chain_mix_3840cef2/ (stored 0%)
#   adding: concat_speech/augmented/chain_mix_3840cef2/chain_mix_3840cef2_aug.json (deflated 54%)
#   adding: concat_speech/augmented/chain_mix_3840cef2/chain_mix_3840cef2_aug.wav (deflated 16%)
#   adding: concat_speech/augmented/single_active_039abcba/ (stored 0%)
#   adding: concat_speech/augmented/single_active_039abcba/single_active_039abcba_aug.json (deflated 48%)
#   adding: concat_speech/augmented/single_active_039abcba/single_active_039abcba_aug.wav (deflated 23%)
#   adding: concat_speech/augmented/chain_active_c1e9cf91/ (stored 0%)
#   adding: concat_speech/augmented/chain_active_c1e9cf91/chain_active_c1e9cf91_aug.json (deflated 42%)
#   adding: concat_speech/augmented/chain_active_c1e9cf91/chain_active_c1e9cf91_aug.wav (deflated 16%)
#   adding: concat_speech/augmented/single_active_ed315bfd/ (stored 0%)
#   adding: concat_speech/augmented/single_active_ed315bfd/single_active_ed315bfd_aug.wav (deflated 8%)
#   adding: concat_speech/augmented/single_active_ed315bfd/single_active_ed315bfd_aug.json (deflated 48%)
#   adding: concat_speech/augmented/non_active_e425baae/ (stored 0%)
#   adding: concat_speech/augmented/non_active_e425baae/non_active_e425baae_aug.json (deflated 43%)
#   adding: concat_speech/augmented/non_active_e425baae/non_active_e425baae_aug.wav (deflated 12%)
#   adding: concat_speech/augmented/single_active_207a7fb6/ (stored 0%)
#   adding: concat_speech/augmented/single_active_207a7fb6/single_active_207a7fb6_aug.json (deflated 48%)
#   adding: concat_speech/augmented/single_active_207a7fb6/single_active_207a7fb6_aug.wav (deflated 18%)
#   adding: concat_speech/augmented/non_active_c3816c61/ (stored 0%)
#   adding: concat_speech/augmented/non_active_c3816c61/non_active_c3816c61_aug.wav (deflated 14%)
#   adding: concat_speech/augmented/non_active_c3816c61/non_active_c3816c61_aug.json (deflated 48%)
#   adding: concat_speech/augmented/single_mix_8dbf7b67/ (stored 0%)
#   adding: concat_speech/augmented/single_mix_8dbf7b67/single_mix_8dbf7b67_aug.wav (deflated 24%)
#   adding: concat_speech/augmented/single_mix_8dbf7b67/single_mix_8dbf7b67_aug.json (deflated 56%)
#   adding: concat_speech/augmented/chain_mix_450f00be/ (stored 0%)
#   adding: concat_speech/augmented/chain_mix_450f00be/chain_mix_450f00be_aug.json (deflated 58%)
#   adding: concat_speech/augmented/chain_mix_450f00be/chain_mix_450f00be_aug.wav (deflated 25%)
#   adding: concat_speech/augmented/single_mix_cbff4ab1/ (stored 0%)
#   adding: concat_speech/augmented/single_mix_cbff4ab1/single_mix_cbff4ab1_aug.wav (deflated 9%)
#   adding: concat_speech/augmented/single_mix_cbff4ab1/single_mix_cbff4ab1_aug.json (deflated 54%)
#   adding: concat_speech/augmented/single_mix_967cb815/ (stored 0%)
#   adding: concat_speech/augmented/single_mix_967cb815/single_mix_967cb815_aug.wav (deflated 14%)
#   adding: concat_speech/augmented/single_mix_967cb815/single_mix_967cb815_aug.json (deflated 52%)
#   adding: concat_speech/augmented/chain_mix_c993d5e3/ (stored 0%)
#   adding: concat_speech/augmented/chain_mix_c993d5e3/chain_mix_c993d5e3_aug.wav (deflated 19%)
#   adding: concat_speech/augmented/chain_mix_c993d5e3/chain_mix_c993d5e3_aug.json (deflated 65%)
#   adding: concat_speech/augmented/single_mix_5e6d54b7/ (stored 0%)
#   adding: concat_speech/augmented/single_mix_5e6d54b7/single_mix_5e6d54b7_aug.wav (deflated 16%)
#   adding: concat_speech/augmented/single_mix_5e6d54b7/single_mix_5e6d54b7_aug.json (deflated 58%)
#   adding: concat_speech/augmented/non_active_996571f3/ (stored 0%)
#   adding: concat_speech/augmented/non_active_996571f3/non_active_996571f3_aug.wav (deflated 11%)
#   adding: concat_speech/augmented/non_active_996571f3/non_active_996571f3_aug.json (deflated 41%)
#   adding: concat_speech/augmented/chain_active_9f6ed0a1/ (stored 0%)
#   adding: concat_speech/augmented/chain_active_9f6ed0a1/chain_active_9f6ed0a1_aug.json (deflated 41%)
#   adding: concat_speech/augmented/chain_active_9f6ed0a1/chain_active_9f6ed0a1_aug.wav (deflated 17%)
#   adding: concat_speech/augmented/single_active_55421e8a/ (stored 0%)
#   adding: concat_speech/augmented/single_active_55421e8a/single_active_55421e8a_aug.wav (deflated 6%)
#   adding: concat_speech/augmented/single_active_55421e8a/single_active_55421e8a_aug.json (deflated 48%)
#   adding: concat_speech/augmented/non_active_e25c7975/ (stored 0%)
#   adding: concat_speech/augmented/non_active_e25c7975/non_active_e25c7975_aug.wav (deflated 24%)
#   adding: concat_speech/augmented/non_active_e25c7975/non_active_e25c7975_aug.json (deflated 49%)
#   adding: concat_speech/augmented/chain_active_645cc583/ (stored 0%)
#   adding: concat_speech/augmented/chain_active_645cc583/chain_active_645cc583_aug.json (deflated 48%)
#   adding: concat_speech/augmented/chain_active_645cc583/chain_active_645cc583_aug.wav (deflated 9%)
#   adding: concat_speech/augmented/single_mix_c00a6b90/ (stored 0%)
#   adding: concat_speech/augmented/single_mix_c00a6b90/single_mix_c00a6b90_aug.json (deflated 58%)
#   adding: concat_speech/augmented/single_mix_c00a6b90/single_mix_c00a6b90_aug.wav (deflated 17%)
#   adding: concat_speech/augmented/non_active_4a354df3/ (stored 0%)
#   adding: concat_speech/augmented/non_active_4a354df3/non_active_4a354df3_aug.json (deflated 43%)
#   adding: concat_speech/augmented/non_active_4a354df3/non_active_4a354df3_aug.wav (deflated 10%)
#   adding: concat_speech/augmented/chain_active_680cf0d7/ (stored 0%)
#   adding: concat_speech/augmented/chain_active_680cf0d7/chain_active_680cf0d7_aug.wav (deflated 43%)
#   adding: concat_speech/augmented/chain_active_680cf0d7/chain_active_680cf0d7_aug.json (deflated 48%)
#   adding: concat_speech/augmented/single_mix_bfc767f8/ (stored 0%)
#   adding: concat_speech/augmented/single_mix_bfc767f8/single_mix_bfc767f8_aug.wav (deflated 8%)
#   adding: concat_speech/augmented/single_mix_bfc767f8/single_mix_bfc767f8_aug.json (deflated 54%)
#   adding: concat_speech/augmented/single_active_efa24704/ (stored 0%)
#   adding: concat_speech/augmented/single_active_efa24704/single_active_efa24704_aug.wav (deflated 39%)
#   adding: concat_speech/augmented/single_active_efa24704/single_active_efa24704_aug.json (deflated 49%)
#   adding: concat_speech/augmented/single_active_4d48ebb5/ (stored 0%)
#   adding: concat_speech/augmented/single_active_4d48ebb5/single_active_4d48ebb5_aug.wav (deflated 16%)
#   adding: concat_speech/augmented/single_active_4d48ebb5/single_active_4d48ebb5_aug.json (deflated 48%)
#   adding: concat_speech/augmented/single_active_5f7fed4d/ (stored 0%)
#   adding: concat_speech/augmented/single_active_5f7fed4d/single_active_5f7fed4d_aug.wav (deflated 11%)
#   adding: concat_speech/augmented/single_active_5f7fed4d/single_active_5f7fed4d_aug.json (deflated 48%)
#   adding: concat_speech/augmented/non_active_292e1a69/ (stored 0%)
#   adding: concat_speech/augmented/non_active_292e1a69/non_active_292e1a69_aug.json (deflated 42%)
#   adding: concat_speech/augmented/non_active_292e1a69/non_active_292e1a69_aug.wav (deflated 7%)
#   adding: concat_speech/augmented/chain_mix_cf57547f/ (stored 0%)
#   adding: concat_speech/augmented/chain_mix_cf57547f/chain_mix_cf57547f_aug.json (deflated 61%)
#   adding: concat_speech/augmented/chain_mix_cf57547f/chain_mix_cf57547f_aug.wav (deflated 23%)
#   adding: concat_speech/augmented/single_mix_534c36af/ (stored 0%)
#   adding: concat_speech/augmented/single_mix_534c36af/single_mix_534c36af_aug.json (deflated 54%)
#   adding: concat_speech/augmented/single_mix_534c36af/single_mix_534c36af_aug.wav (deflated 18%)
#   adding: concat_speech/augmented/single_mix_590bab04/ (stored 0%)
#   adding: concat_speech/augmented/single_mix_590bab04/single_mix_590bab04_aug.wav (deflated 18%)
#   adding: concat_speech/augmented/single_mix_590bab04/single_mix_590bab04_aug.json (deflated 54%)
#   adding: concat_speech/augmented/non_active_b33a8886/ (stored 0%)
#   adding: concat_speech/augmented/non_active_b33a8886/non_active_b33a8886_aug.wav (deflated 14%)
#   adding: concat_speech/augmented/non_active_b33a8886/non_active_b33a8886_aug.json (deflated 49%)
#   adding: concat_speech/augmented/non_active_23292275/ (stored 0%)
#   adding: concat_speech/augmented/non_active_23292275/non_active_23292275_aug.json (deflated 42%)
#   adding: concat_speech/augmented/non_active_23292275/non_active_23292275_aug.wav (deflated 19%)
#   adding: concat_speech/augmented/non_active_cc407b25/ (stored 0%)
#   adding: concat_speech/augmented/non_active_cc407b25/non_active_cc407b25_aug.json (deflated 50%)
#   adding: concat_speech/augmented/non_active_cc407b25/non_active_cc407b25_aug.wav (deflated 16%)
#   adding: concat_speech/augmented/non_active_70990891/ (stored 0%)
#   adding: concat_speech/augmented/non_active_70990891/non_active_70990891_aug.wav (deflated 14%)
#   adding: concat_speech/augmented/non_active_70990891/non_active_70990891_aug.json (deflated 51%)
#   adding: concat_speech/augmented/chain_active_cf4605e2/ (stored 0%)
#   adding: concat_speech/augmented/chain_active_cf4605e2/chain_active_cf4605e2_aug.wav (deflated 20%)
#   adding: concat_speech/augmented/chain_active_cf4605e2/chain_active_cf4605e2_aug.json (deflated 47%)
#   adding: concat_speech/augmented/chain_active_f0ab0a1b/ (stored 0%)
#   adding: concat_speech/augmented/chain_active_f0ab0a1b/chain_active_f0ab0a1b_aug.wav (deflated 18%)
#   adding: concat_speech/augmented/chain_active_f0ab0a1b/chain_active_f0ab0a1b_aug.json (deflated 48%)
#   adding: concat_speech/augmented/non_active_6a1b44f5/ (stored 0%)
#   adding: concat_speech/augmented/non_active_6a1b44f5/non_active_6a1b44f5_aug.json (deflated 41%)
#   adding: concat_speech/augmented/non_active_6a1b44f5/non_active_6a1b44f5_aug.wav (deflated 14%)
#   adding: concat_speech/augmented/non_active_7c28fd39/ (stored 0%)
#   adding: concat_speech/augmented/non_active_7c28fd39/non_active_7c28fd39_aug.json (deflated 42%)
#   adding: concat_speech/augmented/non_active_7c28fd39/non_active_7c28fd39_aug.wav (deflated 4%)
#   adding: concat_speech/augmented/non_active_5356b152/ (stored 0%)
#   adding: concat_speech/augmented/non_active_5356b152/non_active_5356b152_aug.json (deflated 48%)
#   adding: concat_speech/augmented/non_active_5356b152/non_active_5356b152_aug.wav (deflated 25%)
#   adding: concat_speech/augmented/chain_mix_0e95bc90/ (stored 0%)
#   adding: concat_speech/augmented/chain_mix_0e95bc90/chain_mix_0e95bc90_aug.wav (deflated 17%)
#   adding: concat_speech/augmented/chain_mix_0e95bc90/chain_mix_0e95bc90_aug.json (deflated 66%)
#   adding: concat_speech/augmented/chain_mix_5ede206a/ (stored 0%)
#   adding: concat_speech/augmented/chain_mix_5ede206a/chain_mix_5ede206a_aug.wav (deflated 10%)
#   adding: concat_speech/augmented/chain_mix_5ede206a/chain_mix_5ede206a_aug.json (deflated 53%)
#   adding: concat_speech/augmented/single_mix_22e14328/ (stored 0%)
#   adding: concat_speech/augmented/single_mix_22e14328/single_mix_22e14328_aug.wav (deflated 20%)
#   adding: concat_speech/augmented/single_mix_22e14328/single_mix_22e14328_aug.json (deflated 53%)
#   adding: concat_speech/augmented/single_mix_9931eede/ (stored 0%)
#   adding: concat_speech/augmented/single_mix_9931eede/single_mix_9931eede_aug.json (deflated 57%)
#   adding: concat_speech/augmented/single_mix_9931eede/single_mix_9931eede_aug.wav (deflated 24%)
#   adding: concat_speech/augmented/chain_active_f0cb82b4/ (stored 0%)
#   adding: concat_speech/augmented/chain_active_f0cb82b4/chain_active_f0cb82b4_aug.wav (deflated 9%)
#   adding: concat_speech/augmented/chain_active_f0cb82b4/chain_active_f0cb82b4_aug.json (deflated 49%)
#   adding: concat_speech/augmented/non_active_15eaa314/ (stored 0%)
#   adding: concat_speech/augmented/non_active_15eaa314/non_active_15eaa314_aug.wav (deflated 14%)
#   adding: concat_speech/augmented/non_active_15eaa314/non_active_15eaa314_aug.json (deflated 43%)
#   adding: concat_speech/augmented/non_active_fae4b021/ (stored 0%)
#   adding: concat_speech/augmented/non_active_fae4b021/non_active_fae4b021_aug.json (deflated 50%)
#   adding: concat_speech/augmented/non_active_fae4b021/non_active_fae4b021_aug.wav (deflated 25%)
#   adding: concat_speech/augmented/chain_mix_aec7e238/ (stored 0%)
#   adding: concat_speech/augmented/chain_mix_aec7e238/chain_mix_aec7e238_aug.json (deflated 54%)
#   adding: concat_speech/augmented/chain_mix_aec7e238/chain_mix_aec7e238_aug.wav (deflated 18%)
#   adding: concat_speech/augmented/single_active_d30161c8/ (stored 0%)
#   adding: concat_speech/augmented/single_active_d30161c8/single_active_d30161c8_aug.wav (deflated 21%)
#   adding: concat_speech/augmented/single_active_d30161c8/single_active_d30161c8_aug.json (deflated 50%)
#   adding: concat_speech/augmented/chain_active_91a712f7/ (stored 0%)
#   adding: concat_speech/augmented/chain_active_91a712f7/chain_active_91a712f7_aug.json (deflated 42%)
#   adding: concat_speech/augmented/chain_active_91a712f7/chain_active_91a712f7_aug.wav (deflated 19%)
#   adding: concat_speech/augmented/single_active_ab809739/ (stored 0%)
#   adding: concat_speech/augmented/single_active_ab809739/single_active_ab809739_aug.wav (deflated 16%)
#   adding: concat_speech/augmented/single_active_ab809739/single_active_ab809739_aug.json (deflated 48%)
#   adding: concat_speech/augmented/chain_active_8f25c9de/ (stored 0%)
#   adding: concat_speech/augmented/chain_active_8f25c9de/chain_active_8f25c9de_aug.wav (deflated 17%)
#   adding: concat_speech/augmented/chain_active_8f25c9de/chain_active_8f25c9de_aug.json (deflated 42%)
#   adding: concat_speech/augmented/non_active_a60965bc/ (stored 0%)
#   adding: concat_speech/augmented/non_active_a60965bc/non_active_a60965bc_aug.wav (deflated 18%)
#   adding: concat_speech/augmented/non_active_a60965bc/non_active_a60965bc_aug.json (deflated 50%)
#   adding: concat_speech/augmented/single_mix_7ced5f18/ (stored 0%)
#   adding: concat_speech/augmented/single_mix_7ced5f18/single_mix_7ced5f18_aug.json (deflated 54%)
#   adding: concat_speech/augmented/single_mix_7ced5f18/single_mix_7ced5f18_aug.wav (deflated 14%)
#   adding: concat_speech/augmented/chain_active_c22e972a/ (stored 0%)
#   adding: concat_speech/augmented/chain_active_c22e972a/chain_active_c22e972a_aug.json (deflated 48%)
#   adding: concat_speech/augmented/chain_active_c22e972a/chain_active_c22e972a_aug.wav (deflated 7%)
#   adding: concat_speech/augmented/single_mix_f1a02038/ (stored 0%)
#   adding: concat_speech/augmented/single_mix_f1a02038/single_mix_f1a02038_aug.wav (deflated 12%)
#   adding: concat_speech/augmented/single_mix_f1a02038/single_mix_f1a02038_aug.json (deflated 54%)
#   adding: concat_speech/augmented/single_active_117bd180/ (stored 0%)
#   adding: concat_speech/augmented/single_active_117bd180/single_active_117bd180_aug.json (deflated 48%)
#   adding: concat_speech/augmented/single_active_117bd180/single_active_117bd180_aug.wav (deflated 18%)
#   adding: concat_speech/augmented/non_active_90df2f65/ (stored 0%)
#   adding: concat_speech/augmented/non_active_90df2f65/non_active_90df2f65_aug.wav (deflated 11%)
#   adding: concat_speech/augmented/non_active_90df2f65/non_active_90df2f65_aug.json (deflated 51%)
#   adding: concat_speech/augmented/chain_mix_f0564778/ (stored 0%)
#   adding: concat_speech/augmented/chain_mix_f0564778/chain_mix_f0564778_aug.json (deflated 53%)
#   adding: concat_speech/augmented/chain_mix_f0564778/chain_mix_f0564778_aug.wav (deflated 12%)
#   adding: concat_speech/augmented/single_active_d1e1068d/ (stored 0%)
#   adding: concat_speech/augmented/single_active_d1e1068d/single_active_d1e1068d_aug.json (deflated 48%)
#   adding: concat_speech/augmented/single_active_d1e1068d/single_active_d1e1068d_aug.wav (deflated 19%)
#   adding: concat_speech/augmented/chain_active_0aa1a5e5/ (stored 0%)
#   adding: concat_speech/augmented/chain_active_0aa1a5e5/chain_active_0aa1a5e5_aug.json (deflated 50%)
#   adding: concat_speech/augmented/chain_active_0aa1a5e5/chain_active_0aa1a5e5_aug.wav (deflated 13%)
#   adding: concat_speech/augmented/single_active_67f7153b/ (stored 0%)
#   adding: concat_speech/augmented/single_active_67f7153b/single_active_67f7153b_aug.json (deflated 48%)
#   adding: concat_speech/augmented/single_active_67f7153b/single_active_67f7153b_aug.wav (deflated 88%)
#   adding: concat_speech/augmented/non_active_11f0eb4d/ (stored 0%)
#   adding: concat_speech/augmented/non_active_11f0eb4d/non_active_11f0eb4d_aug.json (deflated 48%)
#   adding: concat_speech/augmented/non_active_11f0eb4d/non_active_11f0eb4d_aug.wav (deflated 61%)
#   adding: concat_speech/augmented/chain_active_56ebf610/ (stored 0%)
#   adding: concat_speech/augmented/chain_active_56ebf610/chain_active_56ebf610_aug.wav (deflated 10%)
#   adding: concat_speech/augmented/chain_active_56ebf610/chain_active_56ebf610_aug.json (deflated 48%)
#   adding: concat_speech/augmented/chain_active_19b8c389/ (stored 0%)
#   adding: concat_speech/augmented/chain_active_19b8c389/chain_active_19b8c389_aug.json (deflated 48%)
#   adding: concat_speech/augmented/chain_active_19b8c389/chain_active_19b8c389_aug.wav (deflated 9%)
#   adding: concat_speech/augmented/single_active_e5a332b2/ (stored 0%)
#   adding: concat_speech/augmented/single_active_e5a332b2/single_active_e5a332b2_aug.wav (deflated 30%)
#   adding: concat_speech/augmented/single_active_e5a332b2/single_active_e5a332b2_aug.json (deflated 48%)
#   adding: concat_speech/augmented/single_mix_978cc3a8/ (stored 0%)
#   adding: concat_speech/augmented/single_mix_978cc3a8/single_mix_978cc3a8_aug.wav (deflated 19%)
#   adding: concat_speech/augmented/single_mix_978cc3a8/single_mix_978cc3a8_aug.json (deflated 56%)
#   adding: concat_speech/augmented/single_mix_13c37313/ (stored 0%)
#   adding: concat_speech/augmented/single_mix_13c37313/single_mix_13c37313_aug.json (deflated 54%)
#   adding: concat_speech/augmented/single_mix_13c37313/single_mix_13c37313_aug.wav (deflated 10%)
#   adding: concat_speech/augmented/chain_active_2094a9a7/ (stored 0%)
#   adding: concat_speech/augmented/chain_active_2094a9a7/chain_active_2094a9a7_aug.json (deflated 48%)
#   adding: concat_speech/augmented/chain_active_2094a9a7/chain_active_2094a9a7_aug.wav (deflated 10%)
#   adding: concat_speech/augmented/chain_active_d55826db/ (stored 0%)
#   adding: concat_speech/augmented/chain_active_d55826db/chain_active_d55826db_aug.wav (deflated 8%)
#   adding: concat_speech/augmented/chain_active_d55826db/chain_active_d55826db_aug.json (deflated 48%)
#   adding: concat_speech/augmented/non_active_ce05e82d/ (stored 0%)
#   adding: concat_speech/augmented/non_active_ce05e82d/non_active_ce05e82d_aug.wav (deflated 12%)
#   adding: concat_speech/augmented/non_active_ce05e82d/non_active_ce05e82d_aug.json (deflated 42%)
#   adding: concat_speech/augmented/single_mix_594c214c/ (stored 0%)
#   adding: concat_speech/augmented/single_mix_594c214c/single_mix_594c214c_aug.wav (deflated 22%)
#   adding: concat_speech/augmented/single_mix_594c214c/single_mix_594c214c_aug.json (deflated 53%)
#   adding: concat_speech/augmented/non_active_20eae55f/ (stored 0%)
#   adding: concat_speech/augmented/non_active_20eae55f/non_active_20eae55f_aug.wav (deflated 17%)
#   adding: concat_speech/augmented/non_active_20eae55f/non_active_20eae55f_aug.json (deflated 41%)
#   adding: concat_speech/augmented/chain_mix_de4cda8d/ (stored 0%)
#   adding: concat_speech/augmented/chain_mix_de4cda8d/chain_mix_de4cda8d_aug.json (deflated 61%)
#   adding: concat_speech/augmented/chain_mix_de4cda8d/chain_mix_de4cda8d_aug.wav (deflated 30%)
#   adding: concat_speech/augmented/single_mix_70096deb/ (stored 0%)
#   adding: concat_speech/augmented/single_mix_70096deb/single_mix_70096deb_aug.wav (deflated 25%)
#   adding: concat_speech/augmented/single_mix_70096deb/single_mix_70096deb_aug.json (deflated 53%)
#   adding: concat_speech/augmented/non_active_e774ce6b/ (stored 0%)
#   adding: concat_speech/augmented/non_active_e774ce6b/non_active_e774ce6b_aug.json (deflated 42%)
#   adding: concat_speech/augmented/non_active_e774ce6b/non_active_e774ce6b_aug.wav (deflated 13%)
#   adding: concat_speech/augmented/chain_mix_a624add8/ (stored 0%)
#   adding: concat_speech/augmented/chain_mix_a624add8/chain_mix_a624add8_aug.json (deflated 53%)
#   adding: concat_speech/augmented/chain_mix_a624add8/chain_mix_a624add8_aug.wav (deflated 12%)
#   adding: concat_speech/augmented/chain_mix_24f55560/ (stored 0%)
#   adding: concat_speech/augmented/chain_mix_24f55560/chain_mix_24f55560_aug.json (deflated 58%)
#   adding: concat_speech/augmented/chain_mix_24f55560/chain_mix_24f55560_aug.wav (deflated 16%)
#   adding: concat_speech/augmented/chain_active_02ef84c1/ (stored 0%)
#   adding: concat_speech/augmented/chain_active_02ef84c1/chain_active_02ef84c1_aug.wav (deflated 14%)
#   adding: concat_speech/augmented/chain_active_02ef84c1/chain_active_02ef84c1_aug.json (deflated 50%)
#   adding: concat_speech/augmented/chain_active_cf66965a/ (stored 0%)
#   adding: concat_speech/augmented/chain_active_cf66965a/chain_active_cf66965a_aug.wav (deflated 22%)
#   adding: concat_speech/augmented/chain_active_cf66965a/chain_active_cf66965a_aug.json (deflated 50%)
#   adding: concat_speech/augmented/chain_active_d925097c/ (stored 0%)
#   adding: concat_speech/augmented/chain_active_d925097c/chain_active_d925097c_aug.json (deflated 48%)
#   adding: concat_speech/augmented/chain_active_d925097c/chain_active_d925097c_aug.wav (deflated 15%)
#   adding: concat_speech/augmented/non_active_013653eb/ (stored 0%)
#   adding: concat_speech/augmented/non_active_013653eb/non_active_013653eb_aug.wav (deflated 18%)
#   adding: concat_speech/augmented/non_active_013653eb/non_active_013653eb_aug.json (deflated 43%)
#   adding: concat_speech/augmented/single_active_431466f3/ (stored 0%)
#   adding: concat_speech/augmented/single_active_431466f3/single_active_431466f3_aug.wav (deflated 10%)
#   adding: concat_speech/augmented/single_active_431466f3/single_active_431466f3_aug.json (deflated 48%)
#   adding: concat_speech/augmented/chain_active_6874df95/ (stored 0%)
#   adding: concat_speech/augmented/chain_active_6874df95/chain_active_6874df95_aug.json (deflated 49%)
#   adding: concat_speech/augmented/chain_active_6874df95/chain_active_6874df95_aug.wav (deflated 22%)
#   adding: concat_speech/augmented/chain_mix_2f10f638/ (stored 0%)
#   adding: concat_speech/augmented/chain_mix_2f10f638/chain_mix_2f10f638_aug.wav (deflated 17%)
#   adding: concat_speech/augmented/chain_mix_2f10f638/chain_mix_2f10f638_aug.json (deflated 61%)
#   adding: concat_speech/augmented/chain_mix_232fc99f/ (stored 0%)
#   adding: concat_speech/augmented/chain_mix_232fc99f/chain_mix_232fc99f_aug.json (deflated 53%)
#   adding: concat_speech/augmented/chain_mix_232fc99f/chain_mix_232fc99f_aug.wav (deflated 10%)
#   adding: concat_speech/augmented/chain_mix_7b603607/ (stored 0%)
#   adding: concat_speech/augmented/chain_mix_7b603607/chain_mix_7b603607_aug.wav (deflated 16%)
#   adding: concat_speech/augmented/chain_mix_7b603607/chain_mix_7b603607_aug.json (deflated 61%)
#   adding: concat_speech/augmented/chain_mix_a550feec/ (stored 0%)
#   adding: concat_speech/augmented/chain_mix_a550feec/chain_mix_a550feec_aug.wav (deflated 15%)
#   adding: concat_speech/augmented/chain_mix_a550feec/chain_mix_a550feec_aug.json (deflated 62%)
#   adding: concat_speech/augmented/non_active_2c42a5a5/ (stored 0%)
#   adding: concat_speech/augmented/non_active_2c42a5a5/non_active_2c42a5a5_aug.json (deflated 50%)
#   adding: concat_speech/augmented/non_active_2c42a5a5/non_active_2c42a5a5_aug.wav (deflated 17%)
#   adding: concat_speech/augmented/chain_active_d6d3f35d/ (stored 0%)
#   adding: concat_speech/augmented/chain_active_d6d3f35d/chain_active_d6d3f35d_aug.json (deflated 42%)
#   adding: concat_speech/augmented/chain_active_d6d3f35d/chain_active_d6d3f35d_aug.wav (deflated 21%)
#   adding: concat_speech/augmented/single_mix_28fefc37/ (stored 0%)
#   adding: concat_speech/augmented/single_mix_28fefc37/single_mix_28fefc37_aug.json (deflated 58%)
#   adding: concat_speech/augmented/single_mix_28fefc37/single_mix_28fefc37_aug.wav (deflated 11%)
#   adding: concat_speech/augmented/chain_active_dbc538af/ (stored 0%)
#   adding: concat_speech/augmented/chain_active_dbc538af/chain_active_dbc538af_aug.wav (deflated 14%)
#   adding: concat_speech/augmented/chain_active_dbc538af/chain_active_dbc538af_aug.json (deflated 48%)
#   adding: concat_speech/augmented/single_active_88e98267/ (stored 0%)
#   adding: concat_speech/augmented/single_active_88e98267/single_active_88e98267_aug.json (deflated 48%)
#   adding: concat_speech/augmented/single_active_88e98267/single_active_88e98267_aug.wav (deflated 18%)
#   adding: concat_speech/augmented/non_active_c74b196b/ (stored 0%)
#   adding: concat_speech/augmented/non_active_c74b196b/non_active_c74b196b_aug.wav (deflated 8%)
#   adding: concat_speech/augmented/non_active_c74b196b/non_active_c74b196b_aug.json (deflated 42%)
#   adding: concat_speech/augmented/chain_active_2e310faf/ (stored 0%)
#   adding: concat_speech/augmented/chain_active_2e310faf/chain_active_2e310faf_aug.json (deflated 48%)
# ...
#   adding: concat_speech/augmented/single_mix_c82fd715/single_mix_c82fd715_aug.wav (deflated 14%)
#   adding: concat_speech/augmented/single_mix_c82fd715/single_mix_c82fd715_aug.json (deflated 48%)
#   adding: concat_speech/augmented/single_active_f4e81ea3/ (stored 0%)
#   adding: concat_speech/augmented/single_active_f4e81ea3/single_active_f4e81ea3_aug.wav (deflated 15%)
#   adding: concat_speech/augmented/single_active_f4e81ea3/single_active_f4e81ea3_aug.json (deflated 49%)
#   adding: concat_speech/augmented/chain_active_0dfa041a/ (stored 0%)
#   adding: concat_speech/augmented/chain_active_0dfa041a/chain_active_0dfa041a_aug.json (deflated 51%)
#   adding: concat_speech/augmented/chain_active_0dfa041a/chain_active_0dfa041a_aug.wav (deflated 8%)
#   adding: concat_speech/augmented/chain_mix_0a24179d/ (stored 0%)
#   adding: concat_speech/augmented/chain_mix_0a24179d/chain_mix_0a24179d_aug.json (deflated 53%)
#   adding: concat_speech/augmented/chain_mix_0a24179d/chain_mix_0a24179d_aug.wav (deflated 23%)
#   adding: concat_speech/augmented/non_active_9db02e19/ (stored 0%)
#   adding: concat_speech/augmented/non_active_9db02e19/non_active_9db02e19_aug.json (deflated 43%)
#   adding: concat_speech/augmented/non_active_9db02e19/non_active_9db02e19_aug.wav (deflated 26%)
#   adding: concat_speech/augmented/single_mix_a4e2b3b0/ (stored 0%)
#   adding: concat_speech/augmented/single_mix_a4e2b3b0/single_mix_a4e2b3b0_aug.json (deflated 56%)
#   adding: concat_speech/augmented/single_mix_a4e2b3b0/single_mix_a4e2b3b0_aug.wav (deflated 16%)
#   adding: concat_speech/augmented/non_active_c9acb69c/ (stored 0%)
#   adding: concat_speech/augmented/non_active_c9acb69c/non_active_c9acb69c_aug.json (deflated 43%)
#   adding: concat_speech/augmented/non_active_c9acb69c/non_active_c9acb69c_aug.wav (deflated 10%)
#   adding: concat_speech/augmented/single_mix_cca89f1b/ (stored 0%)
#   adding: concat_speech/augmented/single_mix_cca89f1b/single_mix_cca89f1b_aug.wav (deflated 22%)
#   adding: concat_speech/augmented/single_mix_cca89f1b/single_mix_cca89f1b_aug.json (deflated 53%)
#   adding: concat_speech/augmented/chain_mix_26a5e6f9/ (stored 0%)
#   adding: concat_speech/augmented/chain_mix_26a5e6f9/chain_mix_26a5e6f9_aug.wav (deflated 22%)
#   adding: concat_speech/augmented/chain_mix_26a5e6f9/chain_mix_26a5e6f9_aug.json (deflated 59%)
#   adding: concat_speech/augmented/chain_mix_45f55335/ (stored 0%)
#   adding: concat_speech/augmented/chain_mix_45f55335/chain_mix_45f55335_aug.json (deflated 58%)
#   adding: concat_speech/augmented/chain_mix_45f55335/chain_mix_45f55335_aug.wav (deflated 22%)
#   adding: concat_speech/augmented/single_active_b91db852/ (stored 0%)
#   adding: concat_speech/augmented/single_active_b91db852/single_active_b91db852_aug.wav (deflated 11%)
#   adding: concat_speech/augmented/single_active_b91db852/single_active_b91db852_aug.json (deflated 48%)
#   adding: concat_speech/augmented/chain_mix_d1db06d0/ (stored 0%)
#   adding: concat_speech/augmented/chain_mix_d1db06d0/chain_mix_d1db06d0_aug.wav (deflated 11%)
#   adding: concat_speech/augmented/chain_mix_d1db06d0/chain_mix_d1db06d0_aug.json (deflated 66%)
#   adding: concat_speech/augmented/non_active_88b19918/ (stored 0%)
#   adding: concat_speech/augmented/non_active_88b19918/non_active_88b19918_aug.json (deflated 48%)
#   adding: concat_speech/augmented/non_active_88b19918/non_active_88b19918_aug.wav (deflated 17%)
#   adding: concat_speech/augmented/chain_active_9303487d/ (stored 0%)
#   adding: concat_speech/augmented/chain_active_9303487d/chain_active_9303487d_aug.json (deflated 48%)
#   adding: concat_speech/augmented/chain_active_9303487d/chain_active_9303487d_aug.wav (deflated 11%)
#   adding: concat_speech/augmented/chain_mix_b5f60eb5/ (stored 0%)
#   adding: concat_speech/augmented/chain_mix_b5f60eb5/chain_mix_b5f60eb5_aug.wav (deflated 7%)
#   adding: concat_speech/augmented/chain_mix_b5f60eb5/chain_mix_b5f60eb5_aug.json (deflated 58%)
#   adding: concat_speech/augmented/non_active_60368718/ (stored 0%)
#   adding: concat_speech/augmented/non_active_60368718/non_active_60368718_aug.json (deflated 48%)
#   adding: concat_speech/augmented/non_active_60368718/non_active_60368718_aug.wav (deflated 22%)
#   adding: concat_speech/augmented/single_active_9f69825d/ (stored 0%)
#   adding: concat_speech/augmented/single_active_9f69825d/single_active_9f69825d_aug.wav (deflated 27%)
#   adding: concat_speech/augmented/single_active_9f69825d/single_active_9f69825d_aug.json (deflated 48%)
#   adding: concat_speech/augmented/chain_active_7ff9485f/ (stored 0%)
#   adding: concat_speech/augmented/chain_active_7ff9485f/chain_active_7ff9485f_aug.wav (deflated 20%)
#   adding: concat_speech/augmented/chain_active_7ff9485f/chain_active_7ff9485f_aug.json (deflated 42%)
#   adding: concat_speech/augmented/single_active_92607994/ (stored 0%)
#   adding: concat_speech/augmented/single_active_92607994/single_active_92607994_aug.wav (deflated 10%)
#   adding: concat_speech/augmented/single_active_92607994/single_active_92607994_aug.json (deflated 48%)
#   adding: concat_speech/augmented/single_active_bd116cf7/ (stored 0%)
#   adding: concat_speech/augmented/single_active_bd116cf7/single_active_bd116cf7_aug.wav (deflated 9%)
#   adding: concat_speech/augmented/single_active_bd116cf7/single_active_bd116cf7_aug.json (deflated 48%)
#   adding: concat_speech/augmented/chain_active_9d1dd58f/ (stored 0%)
#   adding: concat_speech/augmented/chain_active_9d1dd58f/chain_active_9d1dd58f_aug.wav (deflated 25%)
#   adding: concat_speech/augmented/chain_active_9d1dd58f/chain_active_9d1dd58f_aug.json (deflated 48%)
#   adding: concat_speech/augmented/non_active_7b511deb/ (stored 0%)
#   adding: concat_speech/augmented/non_active_7b511deb/non_active_7b511deb_aug.wav (deflated 10%)
#   adding: concat_speech/augmented/non_active_7b511deb/non_active_7b511deb_aug.json (deflated 42%)
#   adding: concat_speech/augmented/single_mix_7a87e129/ (stored 0%)
#   adding: concat_speech/augmented/single_mix_7a87e129/single_mix_7a87e129_aug.json (deflated 53%)
#   adding: concat_speech/augmented/single_mix_7a87e129/single_mix_7a87e129_aug.wav (deflated 7%)
#   adding: concat_speech/augmented/single_active_27e51f99/ (stored 0%)
#   adding: concat_speech/augmented/single_active_27e51f99/single_active_27e51f99_aug.json (deflated 48%)
#   adding: concat_speech/augmented/single_active_27e51f99/single_active_27e51f99_aug.wav (deflated 15%)
#   adding: concat_speech/augmented/single_mix_ef3735ee/ (stored 0%)
#   adding: concat_speech/augmented/single_mix_ef3735ee/single_mix_ef3735ee_aug.json (deflated 54%)
#   adding: concat_speech/augmented/single_mix_ef3735ee/single_mix_ef3735ee_aug.wav (deflated 13%)
#   adding: concat_speech/augmented/non_active_4e4330bd/ (stored 0%)
#   adding: concat_speech/augmented/non_active_4e4330bd/non_active_4e4330bd_aug.wav (deflated 15%)
#   adding: concat_speech/augmented/non_active_4e4330bd/non_active_4e4330bd_aug.json (deflated 42%)
#   adding: concat_speech/augmented/chain_mix_844aace6/ (stored 0%)
#   adding: concat_speech/augmented/chain_mix_844aace6/chain_mix_844aace6_aug.json (deflated 65%)
#   adding: concat_speech/augmented/chain_mix_844aace6/chain_mix_844aace6_aug.wav (deflated 27%)
#   adding: concat_speech/augmented/chain_active_02aaa184/ (stored 0%)
#   adding: concat_speech/augmented/chain_active_02aaa184/chain_active_02aaa184_aug.json (deflated 50%)
#   adding: concat_speech/augmented/chain_active_02aaa184/chain_active_02aaa184_aug.wav (deflated 25%)
#   adding: concat_speech/augmented/single_mix_32356593/ (stored 0%)
#   adding: concat_speech/augmented/single_mix_32356593/single_mix_32356593_aug.wav (deflated 13%)
#   adding: concat_speech/augmented/single_mix_32356593/single_mix_32356593_aug.json (deflated 53%)
#   adding: concat_speech/augmented/non_active_3c6b6d7d/ (stored 0%)
#   adding: concat_speech/augmented/non_active_3c6b6d7d/non_active_3c6b6d7d_aug.wav (deflated 24%)
#   adding: concat_speech/augmented/non_active_3c6b6d7d/non_active_3c6b6d7d_aug.json (deflated 42%)
#   adding: concat_speech/augmented/single_active_6fab1bf3/ (stored 0%)
#   adding: concat_speech/augmented/single_active_6fab1bf3/single_active_6fab1bf3_aug.wav (deflated 23%)
#   adding: concat_speech/augmented/single_active_6fab1bf3/single_active_6fab1bf3_aug.json (deflated 50%)
#   adding: concat_speech/augmented/single_mix_05a2369c/ (stored 0%)
#   adding: concat_speech/augmented/single_mix_05a2369c/single_mix_05a2369c_aug.json (deflated 63%)
#   adding: concat_speech/augmented/single_mix_05a2369c/single_mix_05a2369c_aug.wav (deflated 7%)
#   adding: concat_speech/augmented/chain_active_4de5cb1c/ (stored 0%)
#   adding: concat_speech/augmented/chain_active_4de5cb1c/chain_active_4de5cb1c_aug.json (deflated 48%)
#   adding: concat_speech/augmented/chain_active_4de5cb1c/chain_active_4de5cb1c_aug.wav (deflated 12%)
#   adding: concat_speech/augmented/chain_active_942d7623/ (stored 0%)
#   adding: concat_speech/augmented/chain_active_942d7623/chain_active_942d7623_aug.wav (deflated 11%)
#   adding: concat_speech/augmented/chain_active_942d7623/chain_active_942d7623_aug.json (deflated 48%)
#   adding: concat_speech/augmented/chain_active_4aeb0bc2/ (stored 0%)
#   adding: concat_speech/augmented/chain_active_4aeb0bc2/chain_active_4aeb0bc2_aug.json (deflated 47%)
#   adding: concat_speech/augmented/chain_active_4aeb0bc2/chain_active_4aeb0bc2_aug.wav (deflated 11%)
#   adding: concat_speech/augmented/chain_active_a86fb415/ (stored 0%)
#   adding: concat_speech/augmented/chain_active_a86fb415/chain_active_a86fb415_aug.json (deflated 42%)
#   adding: concat_speech/augmented/chain_active_a86fb415/chain_active_a86fb415_aug.wav (deflated 13%)
#   adding: concat_speech/augmented/single_mix_9b170b10/ (stored 0%)
#   adding: concat_speech/augmented/single_mix_9b170b10/single_mix_9b170b10_aug.wav (deflated 16%)
#   adding: concat_speech/augmented/single_mix_9b170b10/single_mix_9b170b10_aug.json (deflated 54%)
#   adding: concat_speech/augmented/single_active_bb8a86aa/ (stored 0%)
#   adding: concat_speech/augmented/single_active_bb8a86aa/single_active_bb8a86aa_aug.json (deflated 48%)
#   adding: concat_speech/augmented/single_active_bb8a86aa/single_active_bb8a86aa_aug.wav (deflated 12%)
#   adding: concat_speech/augmented/single_mix_73399e43/ (stored 0%)
#   adding: concat_speech/augmented/single_mix_73399e43/single_mix_73399e43_aug.json (deflated 58%)
#   adding: concat_speech/augmented/single_mix_73399e43/single_mix_73399e43_aug.wav (deflated 35%)
#   adding: concat_speech/augmented/chain_active_edfedadb/ (stored 0%)
#   adding: concat_speech/augmented/chain_active_edfedadb/chain_active_edfedadb_aug.wav (deflated 20%)
#   adding: concat_speech/augmented/chain_active_edfedadb/chain_active_edfedadb_aug.json (deflated 48%)
#   adding: concat_speech/augmented/single_active_0ff48234/ (stored 0%)
#   adding: concat_speech/augmented/single_active_0ff48234/single_active_0ff48234_aug.json (deflated 48%)
#   adding: concat_speech/augmented/single_active_0ff48234/single_active_0ff48234_aug.wav (deflated 10%)
#   adding: concat_speech/augmented/chain_active_9a3c1813/ (stored 0%)
#   adding: concat_speech/augmented/chain_active_9a3c1813/chain_active_9a3c1813_aug.json (deflated 50%)
#   adding: concat_speech/augmented/chain_active_9a3c1813/chain_active_9a3c1813_aug.wav (deflated 21%)
#   adding: concat_speech/augmented/non_active_c1778b77/ (stored 0%)
#   adding: concat_speech/augmented/non_active_c1778b77/non_active_c1778b77_aug.wav (deflated 15%)
#   adding: concat_speech/augmented/non_active_c1778b77/non_active_c1778b77_aug.json (deflated 41%)
#   adding: concat_speech/augmented/chain_active_682756bc/ (stored 0%)
#   adding: concat_speech/augmented/chain_active_682756bc/chain_active_682756bc_aug.json (deflated 48%)
#   adding: concat_speech/augmented/chain_active_682756bc/chain_active_682756bc_aug.wav (deflated 8%)
#   adding: concat_speech/augmented/chain_mix_1c400ee3/ (stored 0%)
#   adding: concat_speech/augmented/chain_mix_1c400ee3/chain_mix_1c400ee3_aug.wav (deflated 41%)
#   adding: concat_speech/augmented/chain_mix_1c400ee3/chain_mix_1c400ee3_aug.json (deflated 53%)
#   adding: concat_speech/augmented/non_active_5f3113c8/ (stored 0%)
#   adding: concat_speech/augmented/non_active_5f3113c8/non_active_5f3113c8_aug.wav (deflated 9%)
#   adding: concat_speech/augmented/non_active_5f3113c8/non_active_5f3113c8_aug.json (deflated 42%)
#   adding: concat_speech/augmented/non_active_e9b18feb/ (stored 0%)
#   adding: concat_speech/augmented/non_active_e9b18feb/non_active_e9b18feb_aug.wav (deflated 13%)
#   adding: concat_speech/augmented/non_active_e9b18feb/non_active_e9b18feb_aug.json (deflated 42%)
#   adding: concat_speech/augmented/single_active_d79c64da/ (stored 0%)
#   adding: concat_speech/augmented/single_active_d79c64da/single_active_d79c64da_aug.json (deflated 50%)
#   adding: concat_speech/augmented/single_active_d79c64da/single_active_d79c64da_aug.wav (deflated 6%)
#   adding: concat_speech/augmented/single_active_2c8f7b1b/ (stored 0%)
#   adding: concat_speech/augmented/single_active_2c8f7b1b/single_active_2c8f7b1b_aug.json (deflated 48%)
#   adding: concat_speech/augmented/single_active_2c8f7b1b/single_active_2c8f7b1b_aug.wav (deflated 18%)
#   adding: concat_speech/augmented/chain_active_9b3cee56/ (stored 0%)
#   adding: concat_speech/augmented/chain_active_9b3cee56/chain_active_9b3cee56_aug.json (deflated 48%)
#   adding: concat_speech/augmented/chain_active_9b3cee56/chain_active_9b3cee56_aug.wav (deflated 17%)
#   adding: concat_speech/augmented/single_active_f29cc8bb/ (stored 0%)
#   adding: concat_speech/augmented/single_active_f29cc8bb/single_active_f29cc8bb_aug.json (deflated 48%)
#   adding: concat_speech/augmented/single_active_f29cc8bb/single_active_f29cc8bb_aug.wav (deflated 12%)
#   adding: concat_speech/augmented/chain_active_d43f2315/ (stored 0%)
#   adding: concat_speech/augmented/chain_active_d43f2315/chain_active_d43f2315_aug.json (deflated 47%)
#   adding: concat_speech/augmented/chain_active_d43f2315/chain_active_d43f2315_aug.wav (deflated 7%)
#   adding: concat_speech/augmented/non_active_20d5d4ff/ (stored 0%)
#   adding: concat_speech/augmented/non_active_20d5d4ff/non_active_20d5d4ff_aug.json (deflated 50%)
#   adding: concat_speech/augmented/non_active_20d5d4ff/non_active_20d5d4ff_aug.wav (deflated 30%)
#   adding: concat_speech/augmented/chain_active_9753b5c9/ (stored 0%)
#   adding: concat_speech/augmented/chain_active_9753b5c9/chain_active_9753b5c9_aug.json (deflated 42%)
#   adding: concat_speech/augmented/chain_active_9753b5c9/chain_active_9753b5c9_aug.wav (deflated 10%)
#   adding: concat_speech/augmented/non_active_b6deff93/ (stored 0%)
#   adding: concat_speech/augmented/non_active_b6deff93/non_active_b6deff93_aug.json (deflated 42%)
#   adding: concat_speech/augmented/non_active_b6deff93/non_active_b6deff93_aug.wav (deflated 15%)
#   adding: concat_speech/augmented/chain_active_ba4ec47f/ (stored 0%)
#   adding: concat_speech/augmented/chain_active_ba4ec47f/chain_active_ba4ec47f_aug.wav (deflated 28%)
#   adding: concat_speech/augmented/chain_active_ba4ec47f/chain_active_ba4ec47f_aug.json (deflated 42%)
#   adding: concat_speech/augmented/chain_active_e641c474/ (stored 0%)
#   adding: concat_speech/augmented/chain_active_e641c474/chain_active_e641c474_aug.wav (deflated 7%)
#   adding: concat_speech/augmented/chain_active_e641c474/chain_active_e641c474_aug.json (deflated 48%)
#   adding: concat_speech/augmented/single_active_d7c65ef8/ (stored 0%)
#   adding: concat_speech/augmented/single_active_d7c65ef8/single_active_d7c65ef8_aug.json (deflated 47%)
#   adding: concat_speech/augmented/single_active_d7c65ef8/single_active_d7c65ef8_aug.wav (deflated 6%)
#   adding: concat_speech/augmented/single_active_9fc26100/ (stored 0%)
#   adding: concat_speech/augmented/single_active_9fc26100/single_active_9fc26100_aug.wav (deflated 8%)
#   adding: concat_speech/augmented/single_active_9fc26100/single_active_9fc26100_aug.json (deflated 47%)
#   adding: concat_speech/augmented/chain_mix_c68fe32e/ (stored 0%)
#   adding: concat_speech/augmented/chain_mix_c68fe32e/chain_mix_c68fe32e_aug.json (deflated 53%)
#   adding: concat_speech/augmented/chain_mix_c68fe32e/chain_mix_c68fe32e_aug.wav (deflated 11%)
