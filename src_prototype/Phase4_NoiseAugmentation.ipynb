# %% [markdown]
# <a href="https://colab.research.google.com/github/10udCryp7/TV-command-synthesis/blob/main/src_prototype/Phase4_NoiseAugmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import random
import numpy as np
import torch
import torchaudio
from copy import deepcopy
import json
from typing import List, Dict

class NoiseAugmentor:
    def __init__(self,
                 noise_folders,
                 target_sr=16000,
                 snr_range=(-5, 20),
                 prepend_range_s=(2, 5),   # giây
                 append_range_s=(2, 5),    # giây
                 overlap_range_s=(2, 5),   # giây
                 seed=None):
        self.noise_files = []
        for folder in noise_folders:
            for f in os.listdir(folder):
                if f.endswith(".wav"):
                    self.noise_files.append(os.path.join(folder, f))
        assert len(self.noise_files) > 0, "No noise files found!"

        self.sr = target_sr
        self.snr_range = snr_range
        self.prepend_range_s = prepend_range_s
        self.append_range_s = append_range_s
        self.overlap_range_s = overlap_range_s
        if seed is not None:
          random.seed(seed)
          np.random.seed(seed)
          torch.manual_seed(seed)

    def _sec2samples(self, sec):
        return int(sec * self.sr)

    def _load_audio(self, path):
        wav, sr = torchaudio.load(path)
        wav = wav.mean(dim=0, keepdim=True)  # mono
        if sr != self.sr:
            wav = torchaudio.functional.resample(wav, sr, self.sr)
        return wav.squeeze(0)

    def _scale_noise(self, clean, noise, snr_db):
        Px = clean.pow(2).mean()
        Pn = noise.pow(2).mean() + 1e-12
        k = torch.sqrt(Px / (Pn * (10**(snr_db/10))))
        return noise * k

    def _sample_noise_file(self):
        f = random.choice(self.noise_files)
        return self._load_audio(f), f

    def _sample_noise_segment(self, noise, dur_samples):
        if noise.shape[-1] <= dur_samples:
            # noise ngắn quá → lặp/pad
            reps = (dur_samples // noise.shape[-1]) + 1
            noise = noise.repeat(reps)[:dur_samples]
            return noise
        else:
            start = random.randint(0, noise.shape[-1] - dur_samples)
            return noise[start:start+dur_samples]

    def _shift_labels(self, labels, shift_s):
        shifted = []
        for l in labels:
            shifted.append({
                "label": l["label"],
                "start": l["start"] + shift_s,
                "end": l["end"] + shift_s
            })
        return shifted

    def _append_noise_label(self, labels, start_s, end_s):
        labels = deepcopy(labels)
        labels.append({"label": "noise", "start": start_s, "end": end_s})
        return labels

    def _merge_overlap_labels(self, labels, noise_start, noise_end):
        new_labels = deepcopy(labels)
        add_noise = []
        for l in labels:
            if l["label"] == "active":
                if noise_end <= l["start"] or noise_start >= l["end"]:
                    continue  # không chồng
                # noise nhô ra bên trái
                if noise_start < l["start"]:
                    add_noise.append({"label": "noise", "start": noise_start, "end": l["start"]})
                # noise nhô ra bên phải
                if noise_end > l["end"]:
                    add_noise.append({"label": "noise", "start": l["end"], "end": noise_end})
        new_labels.extend(add_noise)
        return new_labels

    def _load_labels(self, json_path: str) -> List[Dict]:
        """
        Đọc file JSON label (dạng list segment) và trả về list dict.

        Args:
            json_path (str): đường dẫn tới file .json

        Returns:
            List[Dict]: danh sách label segment, mỗi phần tử có keys: "label", "start", "end"
        """
        with open(json_path, "r", encoding="utf-8") as f:
            labels = json.load(f)

        # đảm bảo dữ liệu hợp lệ (optional)
        cleaned = []
        for seg in labels:
            if all(k in seg for k in ["label", "start", "end"]):
                cleaned.append({
                    "label": str(seg["label"]),
                    "start": float(seg["start"]),
                    "end": float(seg["end"])
                })
        return cleaned


    def augment(self, clean_path, labels_path, mode=None, custom_snr = None, custom_noise = None, custom_noise_path = None):
        labels = self._load_labels(labels_path)
        clean = self._load_audio(clean_path)
        speech_len = clean.shape[-1]
        speech_dur = speech_len / self.sr

        if custom_noise is not None:
          noise = custom_noise
          noise_path = custom_noise_path
        else:
          noise, noise_path = self._sample_noise_file()
        if mode is None:
            mode = random.choice(["overlap","prepend", "overlap", "append", "overlap"])
        if custom_snr:
          snr_db = custom_snr
        else:
          snr_db = random.uniform(*self.snr_range)

        if mode == "prepend":
            dur_s = random.uniform(*self.prepend_range_s)
            dur_samples = self._sec2samples(dur_s)
            seg = self._sample_noise_segment(noise, dur_samples)
            out = torch.cat([seg, clean])
            new_labels = self._shift_labels(labels, dur_s)
            new_labels = self._append_noise_label(new_labels, 0, dur_s)

        elif mode == "append":
            dur_s = random.uniform(*self.append_range_s)
            dur_samples = self._sec2samples(dur_s)
            seg = self._sample_noise_segment(noise, dur_samples)
            out = torch.cat([clean, seg])
            new_labels = deepcopy(labels)
            new_labels = self._append_noise_label(new_labels, speech_dur, speech_dur + dur_s)

        elif mode == "overlap":
            dur_s = random.uniform(*self.overlap_range_s)
            dur_samples = min(self._sec2samples(dur_s), speech_len)
            offset = random.randint(0, speech_len - dur_samples)
            offset_s = offset / self.sr
            seg = self._sample_noise_segment(noise, dur_samples)

            noise_aligned = torch.zeros_like(clean)
            noise_aligned[offset:offset+dur_samples] = seg
            noise_scaled = self._scale_noise(clean, noise_aligned, snr_db)
            out = clean + noise_scaled

            noise_start = offset_s
            noise_end = offset_s + dur_s
            new_labels = self._merge_overlap_labels(labels, noise_start, noise_end)

        metadata = {
            "clean_path": clean_path,
            "noise_path": noise_path,
            "mode": mode,
            "snr_db": snr_db,
            "labels": new_labels,
        }

        return out, metadata

# %%
# !gdown 1ri2VCkL9gkwvgxstEbE6zTqS1GpgSXZy
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1ri2VCkL9gkwvgxstEbE6zTqS1GpgSXZy
# From (redirected): https://drive.google.com/uc?id=1ri2VCkL9gkwvgxstEbE6zTqS1GpgSXZy&confirm=t&uuid=4e914a25-dad3-45e5-b84b-4499570e2eff
# To: /content/sample-5000-vctk-concat.zip
# 100% 413M/413M [00:09<00:00, 45.8MB/s]

# %%
# !unzip -q sample-5000-vctk-concat.zip

# %%
# !wget -O musan.tar.gz https://www.openslr.org/resources/17/musan.tar.gz
# Out:
# --2025-08-28 03:36:33--  https://www.openslr.org/resources/17/musan.tar.gz
# Resolving www.openslr.org (www.openslr.org)... 136.243.171.4
# Connecting to www.openslr.org (www.openslr.org)|136.243.171.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 11086114085 (10G) [application/x-gzip]
# Saving to: ‘musan.tar.gz’
#
# musan.tar.gz        100%[===================>]  10.32G  13.4MB/s    in 12m 49s
#
# 2025-08-28 03:49:23 (13.8 MB/s) - ‘musan.tar.gz’ saved [11086114085/11086114085]

# %%
# !tar -xzf musan.tar.gz

# %%
NOISE_FOLDERS = [
    "/content/musan/speech/us-gov",
    "/content/musan/speech/librivox"
]

# %%
import os
import json
import soundfile as sf
from tqdm import tqdm  # thêm tqdm

OUTPUT_DIR = "/content/concat_speech/augmented"

def main(custom_mode = False):
    na = NoiseAugmentor(
        noise_folders=NOISE_FOLDERS
    )

    input_root = "/content/concat_speech/sample"

    # dùng tqdm để có progress bar
    for file_folder in tqdm(os.listdir(input_root), desc="Augmenting"):
        folder_path = os.path.join(input_root, file_folder)
        if not os.path.isdir(folder_path):
            continue

        audio_name = f"{file_folder}_concat"
        json_name = f"{file_folder}"

        file_path = os.path.join(folder_path, audio_name + '.wav')
        label_path = os.path.join(folder_path, json_name + '.json')
        if custom_mode:
          snr_ranges = [
              (-5, 0),
              (0, 5),
              (5, 10),
              (10, 15),
              (15, 20)
          ]
          for i in range(5):
            custom_noise, custom_noise_path = na._sample_noise_file()
            for idx, snr_range in enumerate(snr_ranges):
              custom_snr_db = random.uniform(*snr_range)
              out, meta = na.augment(
                  clean_path=file_path,
                  labels_path=label_path,
                  custom_snr = custom_snr_db,
                  custom_noise = custom_noise,
                  custom_noise_path = custom_noise_path
              )
              # make output folder
              out_folder = os.path.join(OUTPUT_DIR, file_folder)
              os.makedirs(out_folder, exist_ok=True)

              # export audio (soundfile expects [T, C] or [T,])
              out_audio_path = os.path.join(out_folder, audio_name.replace("_concat", "_aug") + f'{i}-{idx}' + '.wav')
              sf.write(out_audio_path, out.squeeze(0).numpy().T, na.sr)

              # export metadata
              out_json_path = os.path.join(out_folder, json_name + "_aug" + f'{i}-{idx}' + '.json')
              with open(out_json_path, "w", encoding="utf-8") as f:
                  json.dump(meta, f, indent=2, ensure_ascii=False)
        # augment
        out, meta = na.augment(
            clean_path=file_path,
            labels_path=label_path,
        )

        # make output folder
        out_folder = os.path.join(OUTPUT_DIR, file_folder)
        os.makedirs(out_folder, exist_ok=True)

        # export audio (soundfile expects [T, C] or [T,])
        out_audio_path = os.path.join(out_folder, audio_name.replace("_concat", "_aug") + '.wav')
        sf.write(out_audio_path, out.squeeze(0).numpy().T, na.sr)

        # export metadata
        out_json_path = os.path.join(out_folder, json_name + "_aug.json")
        with open(out_json_path, "w", encoding="utf-8") as f:
            json.dump(meta, f, indent=2, ensure_ascii=False)

# %%
main(custom_mode=True)
# Out:
# Augmenting:   0%|          | 0/3021 [00:00<?, ?it/s]/usr/local/lib/python3.12/dist-packages/torchaudio/_backend/utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/ffmpeg.py:88: UserWarning: torio.io._streaming_media_decoder.StreamingMediaDecoder has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   s = torchaudio.io.StreamReader(src, format, None, buffer_size)
# Augmenting:   1%|          | 34/3021 [01:07<1:38:49,  1.99s/it]Exception ignored in: <generator object tqdm.__iter__ at 0x7f9ab0d743a0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/tqdm/std.py", line 1196, in __iter__
#     self.close()
#   File "/usr/local/lib/python3.12/dist-packages/tqdm/std.py", line 1302, in close
#     self.display(pos=0)
#   File "/usr/local/lib/python3.12/dist-packages/tqdm/std.py", line 1495, in display
#     self.sp(self.__str__() if msg is None else msg)
#   File "/usr/local/lib/python3.12/dist-packages/tqdm/std.py", line 459, in print_status
#     fp_write('\r' + s + (' ' * max(last_len[0] - len_s, 0)))
#   File "/usr/local/lib/python3.12/dist-packages/tqdm/std.py", line 453, in fp_write
#     fp_flush()
#   File "/usr/local/lib/python3.12/dist-packages/tqdm/utils.py", line 196, in inner
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/ipykernel/iostream.py", line 483, in flush
#   File "/usr/local/lib/python3.12/dist-packages/ipykernel/iostream.py", line 210, in schedule
#     self._event_pipe.send(b"")
#   File "/usr/local/lib/python3.12/dist-packages/zmq/sugar/socket.py", line 707, in send
#     return super().send(data, flags=flags, copy=copy, track=track)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "_zmq.py", line 1092, in zmq.backend.cython._zmq.Socket.send
#   File "_zmq.py", line 1140, in zmq.backend.cython._zmq.Socket.send
#   File "_zmq.py", line 1339, in zmq.backend.cython._zmq._send_copy
#   File "_zmq.py", line 160, in zmq.backend.cython._zmq._check_rc
# KeyboardInterrupt:
# Exception ignored in sys.unraisablehook: <built-in function unraisablehook>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/ipykernel/iostream.py", line 483, in flush
#     self.pub_thread.schedule(self._flush)
#   File "/usr/local/lib/python3.12/dist-packages/ipykernel/iostream.py", line 210, in schedule
#     self._event_pipe.send(b"")
#   File "/usr/local/lib/python3.12/dist-packages/zmq/sugar/socket.py", line 707, in send
#     return super().send(data, flags=flags, copy=copy, track=track)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "_zmq.py", line 1092, in zmq.backend.cython._zmq.Socket.send
#   File "_zmq.py", line 1140, in zmq.backend.cython._zmq.Socket.send
#   File "_zmq.py", line 1339, in zmq.backend.cython._zmq._send_copy
#   File "_zmq.py", line 160, in zmq.backend.cython._zmq._check_rc
# KeyboardInterrupt:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-3124510992.py in <cell line: 0>()
# ----> 1 main(custom_mode=True)
#
# /tmp/ipython-input-877040062.py in main(custom_mode)
#      36             for idx, snr_range in enumerate(snr_ranges):
#      37               custom_snr_db = random.uniform(*snr_range)
# ---> 38               out, meta = na.augment(
#      39                   clean_path=file_path,
#      40                   labels_path=label_path,
#
# /tmp/ipython-input-3473765433.py in augment(self, clean_path, labels_path, mode, custom_snr, custom_noise, custom_noise_path)
#     122     def augment(self, clean_path, labels_path, mode=None, custom_snr = None, custom_noise = None, custom_noise_path = None):
#     123         labels = self._load_labels(labels_path)
# --> 124         clean = self._load_audio(clean_path)
#     125         speech_len = clean.shape[-1]
#     126         speech_dur = speech_len / self.sr
#
# /tmp/ipython-input-3473765433.py in _load_audio(self, path)
#      38
#      39     def _load_audio(self, path):
# ---> 40         wav, sr = torchaudio.load(path)
#      41         wav = wav.mean(dim=0, keepdim=True)  # mono
#      42         if sr != self.sr:
#
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/utils.py in load(uri, frame_offset, num_frames, normalize, channels_first, format, buffer_size, backend)
#     220         )
#     221         backend = dispatcher(uri, format, backend)
# --> 222         return backend.load(uri, frame_offset, num_frames, normalize, channels_first, format, buffer_size)
#     223
#     224     return load
#
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/ffmpeg.py in load(uri, frame_offset, num_frames, normalize, channels_first, format, buffer_size)
#     295         buffer_size: int = 4096,
#     296     ) -> Tuple[torch.Tensor, int]:
# --> 297         return load_audio(uri, frame_offset, num_frames, normalize, channels_first, format)
#     298
#     299     @staticmethod
#
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/ffmpeg.py in load_audio(src, frame_offset, num_frames, convert, channels_first, format, buffer_size)
#      86     if hasattr(src, "read") and format == "vorbis":
#      87         format = "ogg"
# ---> 88     s = torchaudio.io.StreamReader(src, format, None, buffer_size)
#      89     sample_rate = int(s.get_src_stream_info(s.default_audio_stream).sample_rate)
#      90     filter = _get_load_filter(frame_offset, num_frames, convert)
#
# /usr/local/lib/python3.12/dist-packages/torchaudio/_internal/module_utils.py in wrapped(*args, **kwargs)
#      69             message += f' It will be removed from {"a future" if version is None else "the " + str(version)} release. '
#      70         warnings.warn(message, stacklevel=2)
# ---> 71         return func(*args, **kwargs)
#      72     return wrapped
#      73
#
# /usr/local/lib/python3.12/dist-packages/torio/io/_streaming_media_decoder.py in __init__(self, src, format, option, buffer_size)
#     523             self._be = ffmpeg_ext.StreamingMediaDecoderFileObj(src, format, option, buffer_size)
#     524         else:
# --> 525             self._be = ffmpeg_ext.StreamingMediaDecoder(os.path.normpath(src), format, option)
#     526
#     527         i = self._be.find_best_audio_stream()
#
# KeyboardInterrupt:

# %%
### Multi thread version

import os
import json
import soundfile as sf
import random
from tqdm import tqdm
from concurrent.futures import ProcessPoolExecutor, as_completed

OUTPUT_DIR = "/content/concat_speech/augmented"
INPUT_ROOT = "/content/concat_speech/sample"

def process_folder(file_folder, custom_mode=False):
    na = NoiseAugmentor(noise_folders=NOISE_FOLDERS)

    folder_path = os.path.join(INPUT_ROOT, file_folder)
    if not os.path.isdir(folder_path):
        return None

    audio_name = f"{file_folder}_concat"
    json_name = f"{file_folder}"

    file_path = os.path.join(folder_path, audio_name + '.wav')
    label_path = os.path.join(folder_path, json_name + '.json')

    results = []

    if custom_mode:
        snr_ranges = [(-5,0),(0,5),(5,10),(10,15),(15,20)]
        for i in range(5):
            custom_noise, custom_noise_path = na._sample_noise_file()
            for idx, snr_range in enumerate(snr_ranges):
                custom_snr_db = random.uniform(*snr_range)
                out, meta = na.augment(
                    clean_path=file_path,
                    labels_path=label_path,
                    custom_snr=custom_snr_db,
                    custom_noise=custom_noise,
                    custom_noise_path=custom_noise_path
                )
                # make output folder
                out_folder = os.path.join(OUTPUT_DIR, file_folder)
                os.makedirs(out_folder, exist_ok=True)

                # export audio
                out_audio_path = os.path.join(out_folder, audio_name.replace("_concat", "_aug") + f'{i}-{idx}.wav')
                sf.write(out_audio_path, out.squeeze(0).numpy().T, na.sr)

                # export metadata
                out_json_path = os.path.join(out_folder, json_name + f"_aug{i}-{idx}.json")
                with open(out_json_path, "w", encoding="utf-8") as f:
                    json.dump(meta, f, indent=2, ensure_ascii=False)

                results.append(out_audio_path)

    # augment (default)
    out, meta = na.augment(
        clean_path=file_path,
        labels_path=label_path,
    )

    out_folder = os.path.join(OUTPUT_DIR, file_folder)
    os.makedirs(out_folder, exist_ok=True)

    out_audio_path = os.path.join(out_folder, audio_name.replace("_concat", "_aug") + '.wav')
    sf.write(out_audio_path, out.squeeze(0).numpy().T, na.sr)

    out_json_path = os.path.join(out_folder, json_name + "_aug.json")
    with open(out_json_path, "w", encoding="utf-8") as f:
        json.dump(meta, f, indent=2, ensure_ascii=False)

    results.append(out_audio_path)
    return results


def main(custom_mode=False, max_workers=4):
    folders = [f for f in os.listdir(INPUT_ROOT) if os.path.isdir(os.path.join(INPUT_ROOT, f))]

    with ProcessPoolExecutor(max_workers=max_workers) as executor:
        futures = {executor.submit(process_folder, f, custom_mode): f for f in folders}

        for future in tqdm(as_completed(futures), total=len(folders), desc="Augmenting"):
            try:
                res = future.result()
            except Exception as e:
                print(f"❌ Error in folder {futures[future]}: {e}")

# %%
main(custom_mode=True)
# Out:
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/ffmpeg.py:88: UserWarning: torio.io._streaming_media_decoder.StreamingMediaDecoder has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   s = torchaudio.io.StreamReader(src, format, None, buffer_size)
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/ffmpeg.py:88: UserWarning: torio.io._streaming_media_decoder.StreamingMediaDecoder has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   s = torchaudio.io.StreamReader(src, format, None, buffer_size)
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/ffmpeg.py:88: UserWarning: torio.io._streaming_media_decoder.StreamingMediaDecoder has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   s = torchaudio.io.StreamReader(src, format, None, buffer_size)
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/ffmpeg.py:88: UserWarning: torio.io._streaming_media_decoder.StreamingMediaDecoder has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   s = torchaudio.io.StreamReader(src, format, None, buffer_size)
# Augmenting: 100%|██████████| 3021/3021 [51:37<00:00,  1.03s/it]

# %%
# !zip aug_speech.zip concat_speech/augmented -r
# Out:
# Streaming output truncated to the last 5000 lines.
#   adding: concat_speech/augmented/non_active_a822ae5e/non_active_a822ae5e_aug3-3.json (deflated 42%)
#   adding: concat_speech/augmented/non_active_a822ae5e/non_active_a822ae5e_aug3-2.wav (deflated 19%)
#   adding: concat_speech/augmented/non_active_a822ae5e/non_active_a822ae5e_aug4-3.json (deflated 48%)
#   adding: concat_speech/augmented/non_active_a822ae5e/non_active_a822ae5e_aug1-2.wav (deflated 22%)
#   adding: concat_speech/augmented/non_active_a822ae5e/non_active_a822ae5e_aug3-4.wav (deflated 22%)
#   adding: concat_speech/augmented/non_active_a822ae5e/non_active_a822ae5e_aug4-3.wav (deflated 22%)
#   adding: concat_speech/augmented/non_active_a822ae5e/non_active_a822ae5e_aug3-1.wav (deflated 20%)
#   adding: concat_speech/augmented/non_active_a822ae5e/non_active_a822ae5e_aug1-3.json (deflated 48%)
#   adding: concat_speech/augmented/non_active_a822ae5e/non_active_a822ae5e_aug2-0.json (deflated 48%)
#   adding: concat_speech/augmented/non_active_a822ae5e/non_active_a822ae5e_aug0-4.wav (deflated 18%)
#   adding: concat_speech/augmented/non_active_a822ae5e/non_active_a822ae5e_aug0-0.json (deflated 42%)
#   adding: concat_speech/augmented/non_active_a822ae5e/non_active_a822ae5e_aug.json (deflated 42%)
#   adding: concat_speech/augmented/non_active_a822ae5e/non_active_a822ae5e_aug4-0.json (deflated 48%)
#   adding: concat_speech/augmented/non_active_a822ae5e/non_active_a822ae5e_aug3-0.json (deflated 50%)
#   adding: concat_speech/augmented/non_active_a822ae5e/non_active_a822ae5e_aug2-3.json (deflated 43%)
#   adding: concat_speech/augmented/non_active_a822ae5e/non_active_a822ae5e_aug3-2.json (deflated 50%)
#   adding: concat_speech/augmented/non_active_a822ae5e/non_active_a822ae5e_aug3-3.wav (deflated 18%)
#   adding: concat_speech/augmented/non_active_a822ae5e/non_active_a822ae5e_aug0-2.json (deflated 42%)
#   adding: concat_speech/augmented/single_active_64f2caed/ (stored 0%)
#   adding: concat_speech/augmented/single_active_64f2caed/single_active_64f2caed_aug0-4.wav (deflated 8%)
#   adding: concat_speech/augmented/single_active_64f2caed/single_active_64f2caed_aug1-0.json (deflated 48%)
#   adding: concat_speech/augmented/single_active_64f2caed/single_active_64f2caed_aug2-4.json (deflated 48%)
#   adding: concat_speech/augmented/single_active_64f2caed/single_active_64f2caed_aug2-3.json (deflated 48%)
#   adding: concat_speech/augmented/single_active_64f2caed/single_active_64f2caed_aug0-1.wav (deflated 5%)
#   adding: concat_speech/augmented/single_active_64f2caed/single_active_64f2caed_aug1-3.json (deflated 50%)
#   adding: concat_speech/augmented/single_active_64f2caed/single_active_64f2caed_aug2-2.wav (deflated 7%)
#   adding: concat_speech/augmented/single_active_64f2caed/single_active_64f2caed_aug0-1.json (deflated 48%)
#   adding: concat_speech/augmented/single_active_64f2caed/single_active_64f2caed_aug2-1.json (deflated 48%)
#   adding: concat_speech/augmented/single_active_64f2caed/single_active_64f2caed_aug4-2.json (deflated 48%)
#   adding: concat_speech/augmented/single_active_64f2caed/single_active_64f2caed_aug4-1.json (deflated 48%)
#   adding: concat_speech/augmented/single_active_64f2caed/single_active_64f2caed_aug2-0.wav (deflated 12%)
#   adding: concat_speech/augmented/single_active_64f2caed/single_active_64f2caed_aug1-2.json (deflated 48%)
#   adding: concat_speech/augmented/single_active_64f2caed/single_active_64f2caed_aug3-2.wav (deflated 17%)
#   adding: concat_speech/augmented/single_active_64f2caed/single_active_64f2caed_aug2-2.json (deflated 48%)
#   adding: concat_speech/augmented/single_active_64f2caed/single_active_64f2caed_aug2-0.json (deflated 50%)
#   adding: concat_speech/augmented/single_active_64f2caed/single_active_64f2caed_aug0-2.json (deflated 50%)
#   adding: concat_speech/augmented/single_active_64f2caed/single_active_64f2caed_aug3-3.wav (deflated 20%)
#   adding: concat_speech/augmented/single_active_64f2caed/single_active_64f2caed_aug4-4.json (deflated 48%)
#   adding: concat_speech/augmented/single_active_64f2caed/single_active_64f2caed_aug2-1.wav (deflated 6%)
#   adding: concat_speech/augmented/single_active_64f2caed/single_active_64f2caed_aug3-4.json (deflated 48%)
#   adding: concat_speech/augmented/single_active_64f2caed/single_active_64f2caed_aug3-1.json (deflated 48%)
#   adding: concat_speech/augmented/single_active_64f2caed/single_active_64f2caed_aug1-1.wav (deflated 9%)
#   adding: concat_speech/augmented/single_active_64f2caed/single_active_64f2caed_aug2-4.wav (deflated 12%)
#   adding: concat_speech/augmented/single_active_64f2caed/single_active_64f2caed_aug0-0.json (deflated 48%)
#   adding: concat_speech/augmented/single_active_64f2caed/single_active_64f2caed_aug4-4.wav (deflated 8%)
#   adding: concat_speech/augmented/single_active_64f2caed/single_active_64f2caed_aug1-0.wav (deflated 4%)
#   adding: concat_speech/augmented/single_active_64f2caed/single_active_64f2caed_aug4-2.wav (deflated 6%)
#   adding: concat_speech/augmented/single_active_64f2caed/single_active_64f2caed_aug4-3.wav (deflated 11%)
#   adding: concat_speech/augmented/single_active_64f2caed/single_active_64f2caed_aug.json (deflated 48%)
#   adding: concat_speech/augmented/single_active_64f2caed/single_active_64f2caed_aug4-3.json (deflated 48%)
#   adding: concat_speech/augmented/single_active_64f2caed/single_active_64f2caed_aug3-3.json (deflated 50%)
#   adding: concat_speech/augmented/single_active_64f2caed/single_active_64f2caed_aug.wav (deflated 7%)
#   adding: concat_speech/augmented/single_active_64f2caed/single_active_64f2caed_aug3-0.json (deflated 48%)
#   adding: concat_speech/augmented/single_active_64f2caed/single_active_64f2caed_aug4-1.wav (deflated 7%)
#   adding: concat_speech/augmented/single_active_64f2caed/single_active_64f2caed_aug1-4.json (deflated 48%)
#   adding: concat_speech/augmented/single_active_64f2caed/single_active_64f2caed_aug3-2.json (deflated 48%)
#   adding: concat_speech/augmented/single_active_64f2caed/single_active_64f2caed_aug2-3.wav (deflated 7%)
#   adding: concat_speech/augmented/single_active_64f2caed/single_active_64f2caed_aug3-0.wav (deflated 4%)
#   adding: concat_speech/augmented/single_active_64f2caed/single_active_64f2caed_aug3-1.wav (deflated 5%)
#   adding: concat_speech/augmented/single_active_64f2caed/single_active_64f2caed_aug4-0.json (deflated 48%)
#   adding: concat_speech/augmented/single_active_64f2caed/single_active_64f2caed_aug1-4.wav (deflated 10%)
#   adding: concat_speech/augmented/single_active_64f2caed/single_active_64f2caed_aug1-2.wav (deflated 10%)
#   adding: concat_speech/augmented/single_active_64f2caed/single_active_64f2caed_aug0-0.wav (deflated 4%)
#   adding: concat_speech/augmented/single_active_64f2caed/single_active_64f2caed_aug0-4.json (deflated 48%)
#   adding: concat_speech/augmented/single_active_64f2caed/single_active_64f2caed_aug3-4.wav (deflated 20%)
#   adding: concat_speech/augmented/single_active_64f2caed/single_active_64f2caed_aug1-1.json (deflated 48%)
#   adding: concat_speech/augmented/single_active_64f2caed/single_active_64f2caed_aug0-3.wav (deflated 7%)
#   adding: concat_speech/augmented/single_active_64f2caed/single_active_64f2caed_aug0-3.json (deflated 48%)
#   adding: concat_speech/augmented/single_active_64f2caed/single_active_64f2caed_aug4-0.wav (deflated 4%)
#   adding: concat_speech/augmented/single_active_64f2caed/single_active_64f2caed_aug1-3.wav (deflated 12%)
#   adding: concat_speech/augmented/single_active_64f2caed/single_active_64f2caed_aug0-2.wav (deflated 13%)
#   adding: concat_speech/augmented/chain_mix_afbdd14d/ (stored 0%)
#   adding: concat_speech/augmented/chain_mix_afbdd14d/chain_mix_afbdd14d_aug1-0.wav (deflated 8%)
#   adding: concat_speech/augmented/chain_mix_afbdd14d/chain_mix_afbdd14d_aug0-2.wav (deflated 10%)
#   adding: concat_speech/augmented/chain_mix_afbdd14d/chain_mix_afbdd14d_aug2-0.json (deflated 53%)
#   adding: concat_speech/augmented/chain_mix_afbdd14d/chain_mix_afbdd14d_aug1-1.wav (deflated 16%)
#   adding: concat_speech/augmented/chain_mix_afbdd14d/chain_mix_afbdd14d_aug1-4.wav (deflated 14%)
#   adding: concat_speech/augmented/chain_mix_afbdd14d/chain_mix_afbdd14d_aug3-1.wav (deflated 17%)
#   adding: concat_speech/augmented/chain_mix_afbdd14d/chain_mix_afbdd14d_aug2-4.wav (deflated 15%)
#   adding: concat_speech/augmented/chain_mix_afbdd14d/chain_mix_afbdd14d_aug1-3.wav (deflated 12%)
#   adding: concat_speech/augmented/chain_mix_afbdd14d/chain_mix_afbdd14d_aug0-3.json (deflated 53%)
#   adding: concat_speech/augmented/chain_mix_afbdd14d/chain_mix_afbdd14d_aug0-4.json (deflated 53%)
#   adding: concat_speech/augmented/chain_mix_afbdd14d/chain_mix_afbdd14d_aug1-4.json (deflated 55%)
#   adding: concat_speech/augmented/chain_mix_afbdd14d/chain_mix_afbdd14d_aug2-3.json (deflated 56%)
#   adding: concat_speech/augmented/chain_mix_afbdd14d/chain_mix_afbdd14d_aug0-4.wav (deflated 16%)
#   adding: concat_speech/augmented/chain_mix_afbdd14d/chain_mix_afbdd14d_aug0-0.json (deflated 53%)
#   adding: concat_speech/augmented/chain_mix_afbdd14d/chain_mix_afbdd14d_aug1-1.json (deflated 53%)
#   adding: concat_speech/augmented/chain_mix_afbdd14d/chain_mix_afbdd14d_aug4-1.json (deflated 53%)
#   adding: concat_speech/augmented/chain_mix_afbdd14d/chain_mix_afbdd14d_aug2-4.json (deflated 53%)
#   adding: concat_speech/augmented/chain_mix_afbdd14d/chain_mix_afbdd14d_aug0-1.json (deflated 53%)
#   adding: concat_speech/augmented/chain_mix_afbdd14d/chain_mix_afbdd14d_aug4-3.json (deflated 53%)
#   adding: concat_speech/augmented/chain_mix_afbdd14d/chain_mix_afbdd14d_aug2-2.json (deflated 53%)
#   adding: concat_speech/augmented/chain_mix_afbdd14d/chain_mix_afbdd14d_aug0-2.json (deflated 54%)
#   adding: concat_speech/augmented/chain_mix_afbdd14d/chain_mix_afbdd14d_aug1-3.json (deflated 53%)
#   adding: concat_speech/augmented/chain_mix_afbdd14d/chain_mix_afbdd14d_aug3-4.json (deflated 53%)
#   adding: concat_speech/augmented/chain_mix_afbdd14d/chain_mix_afbdd14d_aug.wav (deflated 17%)
#   adding: concat_speech/augmented/chain_mix_afbdd14d/chain_mix_afbdd14d_a